# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
import glob
import json
import re
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
# for lexical similarity

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
vectorizer = TfidfVectorizer()

# %%
# for semantic similarity

from sentence_transformers import SentenceTransformer
import numpy as np
model = SentenceTransformer('all-MiniLM-L6-v2') # sbert
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# for detecting questions
import re
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Lexical similarity (TF-IDF cosine similarity)

# %%
def lexical_sim(text1, text2):

  tfidf_matrix = vectorizer.fit_transform([text1, text2])
  cos_sim = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0][0]
  return cos_sim

# %% [markdown]
# ## Semantic similarity (embeddings)

# %%
def semantic_sim(text1, text2):

  embeddings = model.encode([text1, text2])
  cos_sim_emb = np.dot(embeddings[0], embeddings[1]) / (np.linalg.norm(embeddings[0]) * np.linalg.norm(embeddings[1]))
  return cos_sim_emb

# %% [markdown]
# ## Quote vs new content

# %%
def compute_quote_ratio(comment_text):
    lines = comment_text.split('\n')
    quoted = [line for line in lines if line.strip().startswith('&gt;')] # > sign
    original = [line for line in lines if not line.strip().startswith('&gt;')]

    quoted_text = ' '.join(quoted).strip()
    original_text = ' '.join(original).strip()

    len_quoted = len(quoted_text.split()) # words
    len_original = len(original_text.split()) # words

    total = len_original + len_quoted # words
    ratio = len_original / total if total > 0 else 0

    return ratio, original_text, len_quoted, len_original

# %%
def count_questions_in_original(original_text):

    sentences = sent_tokenize(original_text)
    question_count = sum(1 for sent in sentences if sent.strip().endswith('?'))

    return question_count

# %% [markdown]
# ## File parsing

# %%
"""
STOPWORDS = set(stopwords.words("english"))

def clean_text(text, STOPWORDS):
  text = text.lower()
  text1 = re.sub(r'http\S+|www\.\S+', '', text)
  text1 = re.sub(r'u\/\w+|r\/\w+', '', text1)
  tokens = [word for word in text1.split() if word.isalpha() and word not in STOPWORDS]
  text1 = " ".join(tokens)
  if len(text1) > 0:
    return text1
  else:
    return text
"""

# %%
def clean_text(text):
  text = text.lower()
  text = re.sub(r'http\S+|www\.\S+', '', text)
  text = re.sub(r'u\/\w+|r\/\w+', '', text)
  return text

# %%
def process_thread(xml_content: str):
    soup = BeautifulSoup(xml_content, features="xml")
    submission = soup.find('submission')
    original_post = submission.find('original_post').text.strip()
    original_post = clean_text(original_post)

    comments = soup.find_all('comment')
    comment_texts = [c.find('text').text.strip() for  c in comments]
    clean_comms = []
    for c in comment_texts:
      c_clean = clean_text(c)
      clean_comms.append(c_clean)

    return original_post, clean_comms

# %%
def analyze_thread(original_post, comment_texts):
    results = []

    # first comment vs original post
    if comment_texts:
        first_comment = comment_texts[0]
        lexical = lexical_sim(original_post, first_comment)
        semantic = semantic_sim(original_post, first_comment)
        ratio, original_text, len_quote, len_original = compute_quote_ratio(first_comment)
        question_count = count_questions_in_original(original_text)
        results.append({
            'comment_id': 'comment_1',
            'lexical_similarity': lexical,
            'semantic_similarity': semantic,
            'new_content_proportion': ratio,
            'len_quote': len_quote,
            'len_original': len_original,
            'question_count': question_count,
        })

    # each comment vs the previous one
    for i, text in enumerate(comment_texts, 1):
      if i != 0 and i < len(comment_texts):
        prev = comment_texts[i - 1]
        curr = comment_texts[i] # starting from the 2nd comment
        lexical = lexical_sim(prev, curr)
        semantic = semantic_sim(prev, curr)
        ratio, original_text, len_quote, len_original = compute_quote_ratio(curr)
        question_count = count_questions_in_original(original_text)
        results.append({
            'comment_id': f"comment_{i + 1}",
            'lexical_similarity': lexical,
            'semantic_similarity': semantic,
            'new_content_proportion': ratio,
            'len_quote': len_quote,
            'len_original': len_original,
            'question_count': question_count
        })

    return results

# %%
def analyze_thread_2(original_post, comment_texts):
    results = []

    # first comment vs original post
    if comment_texts:
        first_comment = comment_texts[0]
        lexical = lexical_sim(original_post, first_comment)
        semantic = semantic_sim(original_post, first_comment)
        ratio, original_text, len_quote, len_original = compute_quote_ratio(first_comment)
        question_count = count_questions_in_original(original_text)
        results.append({
            'comment_id': 'comment_1',
            'lexical_similarity': lexical,
            'semantic_similarity': semantic,
            'new_content_proportion': ratio,
            'len_quote': len_quote,
            'len_original': len_original,
            'question_count': question_count,
        })

    # each comment vs the previous one
    for i, text in enumerate(comment_texts, 1):
      if i != 0 and i < len(comment_texts):
        prev = original_post
        curr = comment_texts[i] # starting from the 2nd comment
        lexical = lexical_sim(prev, curr)
        semantic = semantic_sim(prev, curr)
        ratio, original_text, len_quote, len_original = compute_quote_ratio(curr)
        question_count = count_questions_in_original(original_text)
        results.append({
            'comment_id': f"comment_{i + 1}",
            'lexical_similarity': lexical,
            'semantic_similarity': semantic,
            'new_content_proportion': ratio,
            'len_quote': len_quote,
            'len_original': len_original,
            'question_count': question_count
        })

    return results

# %% [markdown]
# ## Running the code

# %%
cwd = os.getcwd()

# %%
xml_folder = f"{cwd}/100_sample/"
xml_files = glob.glob(os.path.join(xml_folder, "*.xml"))

# %%
all_results = []

for file in xml_files:
    with open(file, 'r', encoding='utf-8') as f:
      xml_content = f.read()
    op, comms = process_thread(xml_content)
    thread_results = analyze_thread_2(op, comms)
    all_results.append({
    'file': os.path.basename(file),
    'similarity_metrics': thread_results
    })

# %%
all_results
# Out:
# [{'file': '113567594.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.48840128378835784),
#     'semantic_similarity': np.float32(0.6072525),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 360,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.44564922223342424),
#     'semantic_similarity': np.float32(0.50172573),
#     'new_content_proportion': 0.728,
#     'len_quote': 34,
#     'len_original': 91,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.37546164666506615),
#     'semantic_similarity': np.float32(0.5452645),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 215,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.21270756717870878),
#     'semantic_similarity': np.float32(0.39616746),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 55,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.2304259404050069),
#     'semantic_similarity': np.float32(0.42465502),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 98,
#     'question_count': 3},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.2825813866566351),
#     'semantic_similarity': np.float32(0.28120932),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 80,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.18846072726343577),
#     'semantic_similarity': np.float32(0.49280474),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 41,
#     'question_count': 1},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.2178265759574778),
#     'semantic_similarity': np.float32(0.42490637),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 328,
#     'question_count': 0}]},
#  {'file': '1082495263.0_2_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.5161550661210889),
#     'semantic_similarity': np.float32(0.32625663),
#     'new_content_proportion': 0.8865248226950354,
#     'len_quote': 16,
#     'len_original': 125,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.3191085103159209),
#     'semantic_similarity': np.float32(0.54017466),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 105,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.5189528042898502),
#     'semantic_similarity': np.float32(0.8105475),
#     'new_content_proportion': 0.8562874251497006,
#     'len_quote': 24,
#     'len_original': 143,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.5532996995980117),
#     'semantic_similarity': np.float32(0.5297045),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 230,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.6744306525702812),
#     'semantic_similarity': np.float32(0.59615266),
#     'new_content_proportion': 0.5833333333333334,
#     'len_quote': 70,
#     'len_original': 98,
#     'question_count': 1},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.1836177878006778),
#     'semantic_similarity': np.float32(0.34503114),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 10,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.2731413264568393),
#     'semantic_similarity': np.float32(0.50886506),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 55,
#     'question_count': 0}]},
#  {'file': '1409948101.0_2_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.1413747022612621),
#     'semantic_similarity': np.float32(0.15716533),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 28,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.14548793729205226),
#     'semantic_similarity': np.float32(0.15057851),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 33,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.05315867958237256),
#     'semantic_similarity': np.float32(0.24995874),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 37,
#     'question_count': 2},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.07417813462073566),
#     'semantic_similarity': np.float32(0.5109181),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 48,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.27637306221984714),
#     'semantic_similarity': np.float32(0.6353676),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 69,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.13711327819685992),
#     'semantic_similarity': np.float32(0.55474544),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 77,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.5107268928964867),
#     'semantic_similarity': np.float32(0.81218266),
#     'new_content_proportion': 0.6357142857142857,
#     'len_quote': 51,
#     'len_original': 89,
#     'question_count': 1}]},
#  {'file': '1378810771.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.4956004816765263),
#     'semantic_similarity': np.float32(0.667209),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 136,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.2457474072339704),
#     'semantic_similarity': np.float32(0.4772671),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 66,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.17833097188316047),
#     'semantic_similarity': np.float32(0.5202845),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 59,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.17909477061664575),
#     'semantic_similarity': np.float32(0.4356976),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 28,
#     'question_count': 2},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.2576320566151201),
#     'semantic_similarity': np.float32(0.7355744),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 81,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.0490833190129797),
#     'semantic_similarity': np.float32(0.33158192),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 16,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.12500145298147142),
#     'semantic_similarity': np.float32(0.3983495),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 242,
#     'question_count': 4}]},
#  {'file': '1437482501.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.3706358656402864),
#     'semantic_similarity': np.float32(0.49729544),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 45,
#     'question_count': 2},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.22472279124142452),
#     'semantic_similarity': np.float32(0.5058898),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 53,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.3304177639535445),
#     'semantic_similarity': np.float32(0.5603366),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 33,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.12333117483241986),
#     'semantic_similarity': np.float32(0.41659242),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.07539578040993625),
#     'semantic_similarity': np.float32(0.7765137),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 17,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.0787446034559451),
#     'semantic_similarity': np.float32(0.6482223),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 10,
#     'question_count': 0}]},
#  {'file': '154839924.0_4_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.4587928931943571),
#     'semantic_similarity': np.float32(0.51283973),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 576,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.404720397004377),
#     'semantic_similarity': np.float32(0.3248428),
#     'new_content_proportion': 0.32142857142857145,
#     'len_quote': 19,
#     'len_original': 9,
#     'question_count': 2},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.09071380384193486),
#     'semantic_similarity': np.float32(0.2794578),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 27,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.07494180300840195),
#     'semantic_similarity': np.float32(0.41699716),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 34,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.28137929920580995),
#     'semantic_similarity': np.float32(0.43684804),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 386,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.4775938010450761),
#     'semantic_similarity': np.float32(0.12914108),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 93,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.20681647358322747),
#     'semantic_similarity': np.float32(0.3015621),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 25,
#     'question_count': 0}]},
#  {'file': '1719432989.0_3_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.36501710633377754),
#     'semantic_similarity': np.float32(0.40946275),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 35,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.29338858042391025),
#     'semantic_similarity': np.float32(0.5574984),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 67,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.26434183542148226),
#     'semantic_similarity': np.float32(0.5101022),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 38,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.15152318152574729),
#     'semantic_similarity': np.float32(0.50723463),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 12,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.31166575766295646),
#     'semantic_similarity': np.float32(0.4956534),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 81,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.22562713626754102),
#     'semantic_similarity': np.float32(0.6281844),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 121,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.21441323522091016),
#     'semantic_similarity': np.float32(0.37234017),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 30,
#     'question_count': 0},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.21556265747204414),
#     'semantic_similarity': np.float32(0.8425044),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 50,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.18369287411907578),
#     'semantic_similarity': np.float32(0.56210464),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 39,
#     'question_count': 0}]},
#  {'file': '1719432989.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.463852250876813),
#     'semantic_similarity': np.float32(0.6625794),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 171,
#     'question_count': 3},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.8476461081366105),
#     'semantic_similarity': np.float32(0.85599166),
#     'new_content_proportion': 0.6553191489361702,
#     'len_quote': 81,
#     'len_original': 154,
#     'question_count': 4},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.1456297185199896),
#     'semantic_similarity': np.float32(0.41866475),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.2432582541444243),
#     'semantic_similarity': np.float32(0.49550772),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 49,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.08122298122548989),
#     'semantic_similarity': np.float32(0.49394947),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 50,
#     'question_count': 2},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.331908459352262),
#     'semantic_similarity': np.float32(0.7307257),
#     'new_content_proportion': 0.7021276595744681,
#     'len_quote': 14,
#     'len_original': 33,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.40674390416158146),
#     'semantic_similarity': np.float32(0.6855576),
#     'new_content_proportion': 0.32142857142857145,
#     'len_quote': 19,
#     'len_original': 9,
#     'question_count': 1},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.022548785830472595),
#     'semantic_similarity': np.float32(0.17488462),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 20,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.48780459374866003),
#     'semantic_similarity': np.float32(0.4256776),
#     'new_content_proportion': 0.6491228070175439,
#     'len_quote': 20,
#     'len_original': 37,
#     'question_count': 1},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.19710905740833543),
#     'semantic_similarity': np.float32(0.22431372),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 21,
#     'question_count': 0},
#    {'comment_id': 'comment_11',
#     'lexical_similarity': np.float64(0.46509120345079624),
#     'semantic_similarity': np.float32(0.39856458),
#     'new_content_proportion': 0.7407407407407407,
#     'len_quote': 14,
#     'len_original': 40,
#     'question_count': 1}]},
#  {'file': '1821161756.0_2_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.49621765329158757),
#     'semantic_similarity': np.float32(0.61011684),
#     'new_content_proportion': 0.7586206896551724,
#     'len_quote': 56,
#     'len_original': 176,
#     'question_count': 5},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.33625296684541206),
#     'semantic_similarity': np.float32(0.5451639),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 52,
#     'question_count': 2},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.10501653762542143),
#     'semantic_similarity': np.float32(0.59032017),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 45,
#     'question_count': 2},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.03987441960973143),
#     'semantic_similarity': np.float32(0.21145709),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.12007571622217152),
#     'semantic_similarity': np.float32(0.39043173),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 20,
#     'question_count': 1},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.04093578014234018),
#     'semantic_similarity': np.float32(0.21559127),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 8,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.04093578014234018),
#     'semantic_similarity': np.float32(0.24615225),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 20,
#     'question_count': 1}]},
#  {'file': '1821161756.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.319613554353971),
#     'semantic_similarity': np.float32(0.46752983),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 30,
#     'question_count': 2},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.05873845056498567),
#     'semantic_similarity': np.float32(0.25860065),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 19,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.3333661448423105),
#     'semantic_similarity': np.float32(0.4042524),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 107,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.2698868649600632),
#     'semantic_similarity': np.float32(0.5599933),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 59,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.2594314089863631),
#     'semantic_similarity': np.float32(0.56596),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 48,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.06767193839070791),
#     'semantic_similarity': np.float32(0.31332847),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 23,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.1346619313171541),
#     'semantic_similarity': np.float32(0.2255023),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 83,
#     'question_count': 1}]},
#  {'file': '2030191996.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.1391107710851161),
#     'semantic_similarity': np.float32(0.5525393),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 32,
#     'question_count': 2},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.1293970006621355),
#     'semantic_similarity': np.float32(0.26666272),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 109,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.28968486176089425),
#     'semantic_similarity': np.float32(0.41248757),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 52,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.2103726979988946),
#     'semantic_similarity': np.float32(0.36641458),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 35,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.3013585035522436),
#     'semantic_similarity': np.float32(0.41105756),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 53,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.20870205729433808),
#     'semantic_similarity': np.float32(0.21487887),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 35,
#     'question_count': 0}]},
#  {'file': '217468142.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.11183029422863137),
#     'semantic_similarity': np.float32(0.48388836),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 18,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.13236616376830332),
#     'semantic_similarity': np.float32(0.5970608),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 82,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.5943513488415435),
#     'semantic_similarity': np.float32(0.5748654),
#     'new_content_proportion': 0.6370370370370371,
#     'len_quote': 49,
#     'len_original': 86,
#     'question_count': 2},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.2721863541258024),
#     'semantic_similarity': np.float32(0.55387187),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 70,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.30049317082198596),
#     'semantic_similarity': np.float32(0.47822613),
#     'new_content_proportion': 0.5789473684210527,
#     'len_quote': 16,
#     'len_original': 22,
#     'question_count': 2},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.18362849416725982),
#     'semantic_similarity': np.float32(0.62024593),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 41,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.37142396082025286),
#     'semantic_similarity': np.float32(0.69895303),
#     'new_content_proportion': 0.7804878048780488,
#     'len_quote': 9,
#     'len_original': 32,
#     'question_count': 2},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.12731813292203234),
#     'semantic_similarity': np.float32(0.5441718),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 45,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.0160958959118525),
#     'semantic_similarity': np.float32(0.48622453),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 17,
#     'question_count': 0},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.0933506422592562),
#     'semantic_similarity': np.float32(0.5163622),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 154,
#     'question_count': 0},
#    {'comment_id': 'comment_11',
#     'lexical_similarity': np.float64(0.12687771023540048),
#     'semantic_similarity': np.float32(0.5945099),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 31,
#     'question_count': 0},
#    {'comment_id': 'comment_12',
#     'lexical_similarity': np.float64(0.17781975445642367),
#     'semantic_similarity': np.float32(0.58339274),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 339,
#     'question_count': 1},
#    {'comment_id': 'comment_13',
#     'lexical_similarity': np.float64(0.4221047800124626),
#     'semantic_similarity': np.float32(0.67096215),
#     'new_content_proportion': 0.22123893805309736,
#     'len_quote': 88,
#     'len_original': 25,
#     'question_count': 0}]},
#  {'file': '223614694.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.5425239148898522),
#     'semantic_similarity': np.float32(0.67643094),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 105,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.35750137043859376),
#     'semantic_similarity': np.float32(0.7008844),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 122,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.1657984837896422),
#     'semantic_similarity': np.float32(0.60922194),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 42,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.15129870965936396),
#     'semantic_similarity': np.float32(0.41997218),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 120,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.46399545362013633),
#     'semantic_similarity': np.float32(0.7835536),
#     'new_content_proportion': 0.86875,
#     'len_quote': 42,
#     'len_original': 278,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.459091822900652),
#     'semantic_similarity': np.float32(0.6562255),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 98,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.22251404016029233),
#     'semantic_similarity': np.float32(0.63910115),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 41,
#     'question_count': 1},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.22069390864883917),
#     'semantic_similarity': np.float32(0.56585455),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 130,
#     'question_count': 1},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.2581598879513984),
#     'semantic_similarity': np.float32(0.5052966),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 175,
#     'question_count': 0},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.3826439875412107),
#     'semantic_similarity': np.float32(0.7753522),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 187,
#     'question_count': 2},
#    {'comment_id': 'comment_11',
#     'lexical_similarity': np.float64(0.34309428133623365),
#     'semantic_similarity': np.float32(0.564909),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 158,
#     'question_count': 3},
#    {'comment_id': 'comment_12',
#     'lexical_similarity': np.float64(0.12112126112213535),
#     'semantic_similarity': np.float32(0.49243614),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 59,
#     'question_count': 0},
#    {'comment_id': 'comment_13',
#     'lexical_similarity': np.float64(0.2791116063404284),
#     'semantic_similarity': np.float32(0.65686655),
#     'new_content_proportion': 0.9817351598173516,
#     'len_quote': 8,
#     'len_original': 430,
#     'question_count': 3}]},
#  {'file': '220698466.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.45005160470559874),
#     'semantic_similarity': np.float32(0.67028975),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 86,
#     'question_count': 2},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.3113045939829402),
#     'semantic_similarity': np.float32(0.4786314),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 92,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.19894654337776105),
#     'semantic_similarity': np.float32(0.63679063),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 56,
#     'question_count': 2},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.060568323425674295),
#     'semantic_similarity': np.float32(0.54800797),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 39,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.13953774516421652),
#     'semantic_similarity': np.float32(0.4781441),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 29,
#     'question_count': 3},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.24988543941489608),
#     'semantic_similarity': np.float32(0.7140963),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 116,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.13379570474806496),
#     'semantic_similarity': np.float32(0.26539522),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 60,
#     'question_count': 0},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.35752042800949646),
#     'semantic_similarity': np.float32(0.5563643),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 183,
#     'question_count': 1},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.5216651882937823),
#     'semantic_similarity': np.float32(0.4856116),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 136,
#     'question_count': 0},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.7176935113753882),
#     'semantic_similarity': np.float32(0.7939026),
#     'new_content_proportion': 0.7627551020408163,
#     'len_quote': 93,
#     'len_original': 299,
#     'question_count': 2}]},
#  {'file': '2366753957.0_5_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.2546240741355147),
#     'semantic_similarity': np.float32(0.54274625),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 58,
#     'question_count': 4},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.21733803909495766),
#     'semantic_similarity': np.float32(0.6244714),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 20,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.2145172108977857),
#     'semantic_similarity': np.float32(0.7009474),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 77,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.23761557765884314),
#     'semantic_similarity': np.float32(0.6269687),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 77,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.22027482059482312),
#     'semantic_similarity': np.float32(0.51736313),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 259,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.2626846003940431),
#     'semantic_similarity': np.float32(0.5317668),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 35,
#     'question_count': 2},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.27534218027748897),
#     'semantic_similarity': np.float32(0.6911628),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 88,
#     'question_count': 0}]},
#  {'file': '2366753957.0_6_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.5843268414206824),
#     'semantic_similarity': np.float32(0.81433207),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 132,
#     'question_count': 4},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.24641362243733167),
#     'semantic_similarity': np.float32(0.5368813),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 30,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.2114242382323001),
#     'semantic_similarity': np.float32(0.14701091),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 38,
#     'question_count': 2},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.05615740149941604),
#     'semantic_similarity': np.float32(0.26757455),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 6,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.06221139478227743),
#     'semantic_similarity': np.float32(0.52694136),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 53,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.08655736958639353),
#     'semantic_similarity': np.float32(0.2910755),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 20,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.08311651807211985),
#     'semantic_similarity': np.float32(0.35121533),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 38,
#     'question_count': 0},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.1403106788728291),
#     'semantic_similarity': np.float32(0.49089134),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 51,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.05689057617901473),
#     'semantic_similarity': np.float32(0.19124414),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 17,
#     'question_count': 0}]},
#  {'file': '2366753957.0_4_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.2022384346503503),
#     'semantic_similarity': np.float32(0.3452236),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 78,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.11560533931025416),
#     'semantic_similarity': np.float32(0.2558891),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.3101779928898417),
#     'semantic_similarity': np.float32(0.8151933),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 31,
#     'question_count': 4},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.3657129540849708),
#     'semantic_similarity': np.float32(0.6344668),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 41,
#     'question_count': 2},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.2216380660776076),
#     'semantic_similarity': np.float32(0.59824777),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 43,
#     'question_count': 1},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.2862530333789438),
#     'semantic_similarity': np.float32(0.76405585),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 55,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.12190312971561934),
#     'semantic_similarity': np.float32(0.5450218),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 57,
#     'question_count': 0}]},
#  {'file': '2366753957.0_8_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.18106117142812916),
#     'semantic_similarity': np.float32(0.40028286),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 33,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.17129029676643384),
#     'semantic_similarity': np.float32(0.6184927),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 13,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.18824519),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 15,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.26800856),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 13,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.1573345632472989),
#     'semantic_similarity': np.float32(0.08718554),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 11,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.08622587033475419),
#     'semantic_similarity': np.float32(0.2535845),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 13,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.06743557494279505),
#     'semantic_similarity': np.float32(0.066116475),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 6,
#     'question_count': 0},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.09841614),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.08736136),
#     'new_content_proportion': 0,
#     'len_quote': 0,
#     'len_original': 0,
#     'question_count': 0},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.07232233),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 9,
#     'question_count': 0},
#    {'comment_id': 'comment_11',
#     'lexical_similarity': np.float64(0.04183711217318288),
#     'semantic_similarity': np.float32(0.41301185),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 18,
#     'question_count': 1},
#    {'comment_id': 'comment_12',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.21018389),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 2,
#     'question_count': 1},
#    {'comment_id': 'comment_13',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.22766314),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 18,
#     'question_count': 1},
#    {'comment_id': 'comment_14',
#     'lexical_similarity': np.float64(0.036805591958917964),
#     'semantic_similarity': np.float32(0.66029036),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 34,
#     'question_count': 0},
#    {'comment_id': 'comment_15',
#     'lexical_similarity': np.float64(0.24843812541331012),
#     'semantic_similarity': np.float32(0.6897543),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 34,
#     'question_count': 1}]},
#  {'file': '2512463257.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.18894698249763842),
#     'semantic_similarity': np.float32(0.5942013),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 127,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.16350382091371235),
#     'semantic_similarity': np.float32(0.6364214),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.3617277984898384),
#     'semantic_similarity': np.float32(0.41394815),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 27,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.029397855758734933),
#     'semantic_similarity': np.float32(0.16076171),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 10,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.07244081925041987),
#     'semantic_similarity': np.float32(0.117764704),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 7,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.11913689236190332),
#     'semantic_similarity': np.float32(0.49350068),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 12,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.05620708772597144),
#     'semantic_similarity': np.float32(0.49925306),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 27,
#     'question_count': 1},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.06707115178537232),
#     'semantic_similarity': np.float32(0.3592117),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 27,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.08731018661416105),
#     'semantic_similarity': np.float32(0.3620373),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 11,
#     'question_count': 0},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.05629715757507138),
#     'semantic_similarity': np.float32(0.3037988),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 9,
#     'question_count': 0},
#    {'comment_id': 'comment_11',
#     'lexical_similarity': np.float64(0.35630042933313805),
#     'semantic_similarity': np.float32(0.59631467),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 15,
#     'question_count': 1},
#    {'comment_id': 'comment_12',
#     'lexical_similarity': np.float64(0.10830156041911583),
#     'semantic_similarity': np.float32(0.16078997),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 6,
#     'question_count': 0},
#    {'comment_id': 'comment_13',
#     'lexical_similarity': np.float64(0.6386053456078569),
#     'semantic_similarity': np.float32(0.721495),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 16,
#     'question_count': 0}]},
#  {'file': '2549309201.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.5298131951128481),
#     'semantic_similarity': np.float32(0.5682952),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 63,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.11392171940126516),
#     'semantic_similarity': np.float32(0.42040712),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.07874460345594508),
#     'semantic_similarity': np.float32(0.23939662),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 12,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.13627634143908643),
#     'semantic_similarity': np.float32(0.31085387),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 6,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.17416372539202574),
#     'semantic_similarity': np.float32(0.13730714),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 68,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.43493929581417484),
#     'semantic_similarity': np.float32(0.8549279),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 157,
#     'question_count': 2},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.7347573680798222),
#     'semantic_similarity': np.float32(0.7675821),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 221,
#     'question_count': 2},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.5951003373951743),
#     'semantic_similarity': np.float32(0.72288066),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 190,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.7226351268792822),
#     'semantic_similarity': np.float32(0.71939445),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 178,
#     'question_count': 1},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.6394830790637582),
#     'semantic_similarity': np.float32(0.81367576),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 198,
#     'question_count': 3},
#    {'comment_id': 'comment_11',
#     'lexical_similarity': np.float64(0.7534928824506231),
#     'semantic_similarity': np.float32(0.73867524),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 294,
#     'question_count': 2},
#    {'comment_id': 'comment_12',
#     'lexical_similarity': np.float64(0.19079003176629825),
#     'semantic_similarity': np.float32(0.48255983),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 24,
#     'question_count': 2},
#    {'comment_id': 'comment_13',
#     'lexical_similarity': np.float64(0.47242834784982607),
#     'semantic_similarity': np.float32(0.67399955),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 162,
#     'question_count': 2},
#    {'comment_id': 'comment_14',
#     'lexical_similarity': np.float64(0.20315296506880098),
#     'semantic_similarity': np.float32(0.48789003),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 60,
#     'question_count': 0},
#    {'comment_id': 'comment_15',
#     'lexical_similarity': np.float64(0.2318967524920727),
#     'semantic_similarity': np.float32(0.6155287),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 102,
#     'question_count': 0}]},
#  {'file': '295203779.0_1_delta_threads.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.12288276416276395),
#     'semantic_similarity': np.float32(0.3535576),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 6,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.1757860783933462),
#     'semantic_similarity': np.float32(0.46182302),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 2,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.19518264),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 11,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.16229017074028848),
#     'semantic_similarity': np.float32(0.512922),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 24,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.14566929876573442),
#     'semantic_similarity': np.float32(0.53809536),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 53,
# ...
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 25,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.05224985350000812),
#     'semantic_similarity': np.float32(0.19900776),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 15,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.06335481222196541),
#     'semantic_similarity': np.float32(0.37656963),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 19,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.07642786054574814),
#     'semantic_similarity': np.float32(0.592616),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 3,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.15064018498706508),
#     'semantic_similarity': np.float32(0.795804),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 5,
#     'question_count': 1},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.04466656076905525),
#     'semantic_similarity': np.float32(0.58733964),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 22,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.08173768603602148),
#     'semantic_similarity': np.float32(0.4230515),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 12,
#     'question_count': 1},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.09208883711147155),
#     'semantic_similarity': np.float32(0.26122257),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 76,
#     'question_count': 1},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.19521299780634493),
#     'semantic_similarity': np.float32(0.6038808),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 17,
#     'question_count': 0},
#    {'comment_id': 'comment_10',
#     'lexical_similarity': np.float64(0.07684458135688034),
#     'semantic_similarity': np.float32(0.59865415),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 40,
#     'question_count': 0}]},
#  {'file': '2547064804.0_7_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.03643235269622797),
#     'semantic_similarity': np.float32(0.36221087),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 13,
#     'question_count': 2},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.14204408924712314),
#     'semantic_similarity': np.float32(0.46525767),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 61,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.15125413909633395),
#     'semantic_similarity': np.float32(0.36092535),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 22,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.15551142863742579),
#     'semantic_similarity': np.float32(0.27393702),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 111,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.06836044757763128),
#     'semantic_similarity': np.float32(0.1672616),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 14,
#     'question_count': 2},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.11931520489039718),
#     'semantic_similarity': np.float32(0.4064084),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 84,
#     'question_count': 0}]},
#  {'file': '2366753957.0_3_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.31126756759336793),
#     'semantic_similarity': np.float32(0.627612),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 42,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.0869060885698947),
#     'semantic_similarity': np.float32(0.3747857),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 12,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.1686568927747246),
#     'semantic_similarity': np.float32(0.6894683),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 10,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.15499261426129987),
#     'semantic_similarity': np.float32(0.10362834),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 17,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.025231702),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 1,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.4494364165239821),
#     'semantic_similarity': np.float32(0.5845769),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 3,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.0976291194530234),
#     'semantic_similarity': np.float32(0.542025),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 57,
#     'question_count': 1},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.06480508022855759),
#     'semantic_similarity': np.float32(0.36543483),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 7,
#     'question_count': 0},
#    {'comment_id': 'comment_9',
#     'lexical_similarity': np.float64(0.0),
#     'semantic_similarity': np.float32(0.25140864),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 15,
#     'question_count': 0}]},
#  {'file': '2676326580.0_26_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.3460597173095314),
#     'semantic_similarity': np.float32(0.52549565),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 183,
#     'question_count': 2},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.2493575002102519),
#     'semantic_similarity': np.float32(0.618927),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 124,
#     'question_count': 4},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.0776816990165684),
#     'semantic_similarity': np.float32(0.19636826),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 29,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.12268329489641752),
#     'semantic_similarity': np.float32(0.5752445),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 31,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.04722035612860628),
#     'semantic_similarity': np.float32(0.09959817),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 5,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.07734781234369076),
#     'semantic_similarity': np.float32(0.06457663),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 10,
#     'question_count': 1},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.12090065602097133),
#     'semantic_similarity': np.float32(0.18144299),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 422,
#     'question_count': 1}]},
#  {'file': '401821196.0_2_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.40539513786119163),
#     'semantic_similarity': np.float32(0.8096057),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 72,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.20416398214962594),
#     'semantic_similarity': np.float32(0.15793945),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 18,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.14566278055575768),
#     'semantic_similarity': np.float32(0.3766074),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 43,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.3495934899610664),
#     'semantic_similarity': np.float32(0.7386035),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 47,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.19844751302117197),
#     'semantic_similarity': np.float32(0.5530634),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 28,
#     'question_count': 0}]},
#  {'file': '363480636.0_5_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.5764053021271205),
#     'semantic_similarity': np.float32(0.7213894),
#     'new_content_proportion': 0.9177215189873418,
#     'len_quote': 13,
#     'len_original': 145,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.912388187990635),
#     'semantic_similarity': np.float32(0.83368856),
#     'new_content_proportion': 0.23834196891191708,
#     'len_quote': 147,
#     'len_original': 46,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.744539435903093),
#     'semantic_similarity': np.float32(0.84249485),
#     'new_content_proportion': 0.7444444444444445,
#     'len_quote': 46,
#     'len_original': 134,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.8820879014712675),
#     'semantic_similarity': np.float32(0.7572874),
#     'new_content_proportion': 0.4,
#     'len_quote': 135,
#     'len_original': 90,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.6740999962135219),
#     'semantic_similarity': np.float32(0.81077206),
#     'new_content_proportion': 0.5609756097560976,
#     'len_quote': 90,
#     'len_original': 115,
#     'question_count': 1},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.7847482427409928),
#     'semantic_similarity': np.float32(0.57299006),
#     'new_content_proportion': 0.5,
#     'len_quote': 116,
#     'len_original': 116,
#     'question_count': 0}]},
#  {'file': '410977978.0_3_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.4610331073275122),
#     'semantic_similarity': np.float32(0.63173664),
#     'new_content_proportion': 0.8425925925925926,
#     'len_quote': 17,
#     'len_original': 91,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.39454580637479464),
#     'semantic_similarity': np.float32(0.36595267),
#     'new_content_proportion': 0.6444444444444445,
#     'len_quote': 16,
#     'len_original': 29,
#     'question_count': 0},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.17489653858297394),
#     'semantic_similarity': np.float32(0.3004282),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 25,
#     'question_count': 0},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.10890235765909699),
#     'semantic_similarity': np.float32(0.3699069),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 23,
#     'question_count': 1},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.12208805981871433),
#     'semantic_similarity': np.float32(0.21187626),
#     'new_content_proportion': 0.41379310344827586,
#     'len_quote': 17,
#     'len_original': 12,
#     'question_count': 0},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.2556912824714648),
#     'semantic_similarity': np.float32(0.40929687),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 59,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.514012516791001),
#     'semantic_similarity': np.float32(0.6347729),
#     'new_content_proportion': 0.21428571428571427,
#     'len_quote': 22,
#     'len_original': 6,
#     'question_count': 0}]},
#  {'file': '410977978.0_4_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.49101830117415063),
#     'semantic_similarity': np.float32(0.27966765),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 129,
#     'question_count': 1},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.0508829336393473),
#     'semantic_similarity': np.float32(0.24575941),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 13,
#     'question_count': 1},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.06882542958855789),
#     'semantic_similarity': np.float32(0.3917438),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 20,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.1572035265388783),
#     'semantic_similarity': np.float32(0.46627092),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 23,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.06808385478217654),
#     'semantic_similarity': np.float32(0.13501364),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 73,
#     'question_count': 0}]},
#  {'file': '442068628.0_4_deltaless_thread.xml',
#   'similarity_metrics': [{'comment_id': 'comment_1',
#     'lexical_similarity': np.float64(0.3348852087515081),
#     'semantic_similarity': np.float32(0.37311283),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 81,
#     'question_count': 0},
#    {'comment_id': 'comment_2',
#     'lexical_similarity': np.float64(0.2573004677608432),
#     'semantic_similarity': np.float32(0.74188256),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 37,
#     'question_count': 2},
#    {'comment_id': 'comment_3',
#     'lexical_similarity': np.float64(0.19095977179345017),
#     'semantic_similarity': np.float32(0.6108393),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 85,
#     'question_count': 1},
#    {'comment_id': 'comment_4',
#     'lexical_similarity': np.float64(0.2075763305019004),
#     'semantic_similarity': np.float32(0.40090257),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 84,
#     'question_count': 0},
#    {'comment_id': 'comment_5',
#     'lexical_similarity': np.float64(0.16413699453151193),
#     'semantic_similarity': np.float32(0.40873995),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 60,
#     'question_count': 4},
#    {'comment_id': 'comment_6',
#     'lexical_similarity': np.float64(0.07454487151154766),
#     'semantic_similarity': np.float32(0.29928103),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 17,
#     'question_count': 0},
#    {'comment_id': 'comment_7',
#     'lexical_similarity': np.float64(0.16363011874981886),
#     'semantic_similarity': np.float32(0.60478365),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 41,
#     'question_count': 0},
#    {'comment_id': 'comment_8',
#     'lexical_similarity': np.float64(0.13295147290727716),
#     'semantic_similarity': np.float32(0.44703427),
#     'new_content_proportion': 1.0,
#     'len_quote': 0,
#     'len_original': 41,
#     'question_count': 0}]}]

# %% [markdown]
# ## Transforming into a df

# %%
import pandas as pd

# %%
flattened = []

for entry in all_results:
  flat_row = {'filename': entry['file']}
  for i, comment in enumerate(entry['similarity_metrics'], start=1):
    prefix = f'c{i}_'
    flat_row[prefix + 'lexical_similarity'] = float(comment['lexical_similarity'])
    flat_row[prefix + 'semantic_similarity'] = float(comment['semantic_similarity'])
    flat_row[prefix + 'new_content_proportion'] = comment['new_content_proportion']
    flat_row[prefix + 'len_quote'] = comment['len_quote']
    flat_row[prefix + 'len_original'] = comment['len_original']
    flat_row[prefix + 'question_count'] = comment['question_count']
  flattened.append(flat_row)

# %%
df = pd.DataFrame(flattened)

# %%
df
# Out:
#                                 filename  c1_lexical_similarity  \
# 0        113567594.0_1_delta_threads.xml               0.488401
# 1       1082495263.0_2_delta_threads.xml               0.516155
# 2       1409948101.0_2_delta_threads.xml               0.141375
# 3       1378810771.0_1_delta_threads.xml               0.495600
# 4       1437482501.0_1_delta_threads.xml               0.370636
# 5        154839924.0_4_delta_threads.xml               0.458793
# 6       1719432989.0_3_delta_threads.xml               0.365017
# 7       1719432989.0_1_delta_threads.xml               0.463852
# 8       1821161756.0_2_delta_threads.xml               0.496218
# 9       1821161756.0_1_delta_threads.xml               0.319614
# 10      2030191996.0_1_delta_threads.xml               0.139111
# 11       217468142.0_1_delta_threads.xml               0.111830
# 12       223614694.0_1_delta_threads.xml               0.542524
# 13       220698466.0_1_delta_threads.xml               0.450052
# 14      2366753957.0_5_delta_threads.xml               0.254624
# 15      2366753957.0_6_delta_threads.xml               0.584327
# 16      2366753957.0_4_delta_threads.xml               0.202238
# 17      2366753957.0_8_delta_threads.xml               0.181061
# 18      2512463257.0_1_delta_threads.xml               0.188947
# 19      2549309201.0_1_delta_threads.xml               0.529813
# 20       295203779.0_1_delta_threads.xml               0.122883
# 21       410977978.0_2_delta_threads.xml               0.221018
# 22       363480636.0_3_delta_threads.xml               0.095007
# 23       442068628.0_1_delta_threads.xml               0.421341
# 24       410977978.0_3_delta_threads.xml               0.221018
# 25   1075040167.0_2_deltaless_thread.xml               0.167597
# 26    113567594.0_4_deltaless_thread.xml               0.382178
# 27    115882088.0_2_deltaless_thread.xml               0.514537
# 28   1409948101.0_8_deltaless_thread.xml               0.528780
# 29  1437482501.0_91_deltaless_thread.xml               0.378414
# 30    144404372.0_8_deltaless_thread.xml               0.582748
# 31    154839924.0_3_deltaless_thread.xml               0.393170
# 32   1719432989.0_1_deltaless_thread.xml               0.198105
# 33    181959121.0_5_deltaless_thread.xml               0.400577
# 34   1821161756.0_9_deltaless_thread.xml               0.433579
# 35  1865427692.0_13_deltaless_thread.xml               0.218838
# 36  1865427692.0_24_deltaless_thread.xml               0.243087
# 37    217468142.0_3_deltaless_thread.xml               0.284283
# 38   2076541612.0_3_deltaless_thread.xml               0.541627
# 39    220698466.0_2_deltaless_thread.xml               0.484017
# 40  2242239967.0_10_deltaless_thread.xml               0.325564
# 41   2366753957.0_2_deltaless_thread.xml               0.253598
# 42   2547064804.0_7_deltaless_thread.xml               0.036432
# 43   2366753957.0_3_deltaless_thread.xml               0.311268
# 44  2676326580.0_26_deltaless_thread.xml               0.346060
# 45    401821196.0_2_deltaless_thread.xml               0.405395
# 46    363480636.0_5_deltaless_thread.xml               0.576405
# 47    410977978.0_3_deltaless_thread.xml               0.461033
# 48    410977978.0_4_deltaless_thread.xml               0.491018
# 49    442068628.0_4_deltaless_thread.xml               0.334885
#
#     c1_semantic_similarity  c1_new_content_proportion  c1_len_quote  \
# 0                 0.607252                   1.000000             0
# 1                 0.326257                   0.886525            16
# 2                 0.157165                   1.000000             0
# 3                 0.667209                   1.000000             0
# 4                 0.497295                   1.000000             0
# 5                 0.512840                   1.000000             0
# 6                 0.409463                   1.000000             0
# 7                 0.662579                   1.000000             0
# 8                 0.610117                   0.758621            56
# 9                 0.467530                   1.000000             0
# 10                0.552539                   1.000000             0
# 11                0.483888                   1.000000             0
# 12                0.676431                   1.000000             0
# 13                0.670290                   1.000000             0
# 14                0.542746                   1.000000             0
# 15                0.814332                   1.000000             0
# 16                0.345224                   1.000000             0
# 17                0.400283                   1.000000             0
# 18                0.594201                   1.000000             0
# 19                0.568295                   1.000000             0
# 20                0.353558                   1.000000             0
# 21                0.291380                   1.000000             0
# 22                0.349584                   1.000000             0
# 23                0.600539                   1.000000             0
# 24                0.291380                   1.000000             0
# 25                0.532530                   1.000000             0
# 26                0.680690                   1.000000             0
# 27                0.481564                   1.000000             0
# 28                0.636798                   0.854749            26
# 29                0.797908                   1.000000             0
# 30                0.432595                   0.842975            19
# 31                0.536343                   1.000000             0
# 32                0.308718                   1.000000             0
# 33                0.579897                   1.000000             0
# 34                0.540526                   0.750000            42
# 35                0.518688                   1.000000             0
# 36                0.572117                   1.000000             0
# 37                0.513910                   1.000000             0
# 38                0.802439                   0.651852            47
# 39                0.522569                   1.000000             0
# 40                0.586046                   1.000000             0
# 41                0.533255                   1.000000             0
# 42                0.362211                   1.000000             0
# 43                0.627612                   1.000000             0
# 44                0.525496                   1.000000             0
# 45                0.809606                   1.000000             0
# 46                0.721389                   0.917722            13
# 47                0.631737                   0.842593            17
# 48                0.279668                   1.000000             0
# 49                0.373113                   1.000000             0
#
#     c1_len_original  c1_question_count  c2_lexical_similarity  \
# 0               360                  0               0.445649
# 1               125                  0               0.319109
# 2                28                  0               0.145488
# 3               136                  1               0.245747
# 4                45                  2               0.224723
# 5               576                  1               0.404720
# 6                35                  0               0.293389
# 7               171                  3               0.847646
# 8               176                  5               0.336253
# 9                30                  2               0.058738
# 10               32                  2               0.129397
# 11               18                  1               0.132366
# 12              105                  1               0.357501
# 13               86                  2               0.311305
# 14               58                  4               0.217338
# 15              132                  4               0.246414
# 16               78                  1               0.115605
# 17               33                  0               0.171290
# 18              127                  1               0.163504
# 19               63                  0               0.113922
# 20                6                  1               0.175786
# 21               32                  1               0.162133
# 22               15                  2               0.110578
# 23              142                  1               0.267939
# 24               32                  1               0.162133
# 25               38                  2               0.124951
# 26              206                  1               0.226192
# 27              183                  0               0.046936
# 28              153                  2               0.199306
# 29               99                  2               0.267907
# 30              102                  1               0.481498
# 31              223                  0               0.185254
# 32                5                  1               0.206137
# 33              137                  0               0.211686
# 34              126                  6               0.266250
# 35               19                  0               0.213712
# 36               28                  0               0.135956
# 37               78                  1               0.183076
# 38               88                  1               0.585000
# 39              104                  0               0.577057
# 40              181                  3               0.302696
# 41               25                  0               0.052250
# 42               13                  2               0.142044
# 43               42                  0               0.086906
# 44              183                  2               0.249358
# 45               72                  0               0.204164
# 46              145                  0               0.912388
# 47               91                  0               0.394546
# 48              129                  1               0.050883
# 49               81                  0               0.257300
#
#     c2_semantic_similarity  c2_new_content_proportion  ...  \
# 0                 0.501726                   0.728000  ...
# 1                 0.540175                   1.000000  ...
# 2                 0.150579                   1.000000  ...
# 3                 0.477267                   1.000000  ...
# 4                 0.505890                   1.000000  ...
# 5                 0.324843                   0.321429  ...
# 6                 0.557498                   1.000000  ...
# 7                 0.855992                   0.655319  ...
# 8                 0.545164                   1.000000  ...
# 9                 0.258601                   1.000000  ...
# 10                0.266663                   1.000000  ...
# 11                0.597061                   1.000000  ...
# 12                0.700884                   1.000000  ...
# 13                0.478631                   1.000000  ...
# 14                0.624471                   1.000000  ...
# 15                0.536881                   1.000000  ...
# 16                0.255889                   1.000000  ...
# 17                0.618493                   1.000000  ...
# 18                0.636421                   1.000000  ...
# 19                0.420407                   1.000000  ...
# 20                0.461823                   1.000000  ...
# 21                0.236270                   1.000000  ...
# 22                0.489149                   1.000000  ...
# 23                0.354145                   1.000000  ...
# 24                0.236270                   1.000000  ...
# 25                0.742181                   1.000000  ...
# 26                0.498424                   1.000000  ...
# 27                0.104968                   1.000000  ...
# 28                0.384009                   1.000000  ...
# 29                0.590192                   0.607843  ...
# 30                0.450702                   0.890909  ...
# 31                0.140086                   1.000000  ...
# 32                0.693122                   1.000000  ...
# 33                0.423181                   1.000000  ...
# 34                0.580353                   1.000000  ...
# 35                0.679982                   1.000000  ...
# 36                0.595426                   1.000000  ...
# 37                0.691962                   1.000000  ...
# 38                0.497069                   0.370968  ...
# 39                0.769766                   0.819672  ...
# 40                0.595431                   1.000000  ...
# 41                0.199008                   1.000000  ...
# 42                0.465258                   1.000000  ...
# 43                0.374786                   1.000000  ...
# 44                0.618927                   1.000000  ...
# 45                0.157939                   1.000000  ...
# 46                0.833689                   0.238342  ...
# 47                0.365953                   0.644444  ...
# 48                0.245759                   1.000000  ...
# 49                0.741883                   1.000000  ...
#
#     c15_new_content_proportion  c15_len_quote  c15_len_original  \
# 0                          NaN            NaN               NaN
# 1                          NaN            NaN               NaN
# 2                          NaN            NaN               NaN
# 3                          NaN            NaN               NaN
# 4                          NaN            NaN               NaN
# 5                          NaN            NaN               NaN
# 6                          NaN            NaN               NaN
# 7                          NaN            NaN               NaN
# 8                          NaN            NaN               NaN
# 9                          NaN            NaN               NaN
# 10                         NaN            NaN               NaN
# 11                         NaN            NaN               NaN
# 12                         NaN            NaN               NaN
# 13                         NaN            NaN               NaN
# 14                         NaN            NaN               NaN
# 15                         NaN            NaN               NaN
# 16                         NaN            NaN               NaN
# 17                    1.000000            0.0              34.0
# 18                         NaN            NaN               NaN
# 19                    1.000000            0.0             102.0
# 20                         NaN            NaN               NaN
# 21                         NaN            NaN               NaN
# 22                    1.000000            0.0             263.0
# 23                         NaN            NaN               NaN
# 24                         NaN            NaN               NaN
# 25                         NaN            NaN               NaN
# 26                         NaN            NaN               NaN
# 27                         NaN            NaN               NaN
# 28                         NaN            NaN               NaN
# 29                         NaN            NaN               NaN
# 30                         NaN            NaN               NaN
# 31                         NaN            NaN               NaN
# 32                         NaN            NaN               NaN
# 33                    0.588235           14.0              20.0
# 34                         NaN            NaN               NaN
# 35                         NaN            NaN               NaN
# 36                         NaN            NaN               NaN
# 37                         NaN            NaN               NaN
# 38                         NaN            NaN               NaN
# 39                         NaN            NaN               NaN
# 40                         NaN            NaN               NaN
# 41                         NaN            NaN               NaN
# 42                         NaN            NaN               NaN
# 43                         NaN            NaN               NaN
# 44                         NaN            NaN               NaN
# 45                         NaN            NaN               NaN
# 46                         NaN            NaN               NaN
# 47                         NaN            NaN               NaN
# 48                         NaN            NaN               NaN
# 49                         NaN            NaN               NaN
#
#     c15_question_count  c16_lexical_similarity  c16_semantic_similarity  \
# 0                  NaN                     NaN                      NaN
# 1                  NaN                     NaN                      NaN
# 2                  NaN                     NaN                      NaN
# 3                  NaN                     NaN                      NaN
# 4                  NaN                     NaN                      NaN
# 5                  NaN                     NaN                      NaN
# 6                  NaN                     NaN                      NaN
# 7                  NaN                     NaN                      NaN
# 8                  NaN                     NaN                      NaN
# 9                  NaN                     NaN                      NaN
# 10                 NaN                     NaN                      NaN
# 11                 NaN                     NaN                      NaN
# 12                 NaN                     NaN                      NaN
# 13                 NaN                     NaN                      NaN
# 14                 NaN                     NaN                      NaN
# 15                 NaN                     NaN                      NaN
# 16                 NaN                     NaN                      NaN
# 17                 1.0                     NaN                      NaN
# 18                 NaN                     NaN                      NaN
# 19                 0.0                     NaN                      NaN
# 20                 NaN                     NaN                      NaN
# 21                 NaN                     NaN                      NaN
# 22                 1.0                     NaN                      NaN
# 23                 NaN                     NaN                      NaN
# 24                 NaN                     NaN                      NaN
# 25                 NaN                     NaN                      NaN
# 26                 NaN                     NaN                      NaN
# 27                 NaN                     NaN                      NaN
# 28                 NaN                     NaN                      NaN
# 29                 NaN                     NaN                      NaN
# 30                 NaN                     NaN                      NaN
# 31                 NaN                     NaN                      NaN
# 32                 NaN                     NaN                      NaN
# 33                 0.0                 0.15818                 0.678911
# 34                 NaN                     NaN                      NaN
# 35                 NaN                     NaN                      NaN
# 36                 NaN                     NaN                      NaN
# 37                 NaN                     NaN                      NaN
# 38                 NaN                     NaN                      NaN
# 39                 NaN                     NaN                      NaN
# 40                 NaN                     NaN                      NaN
# 41                 NaN                     NaN                      NaN
# 42                 NaN                     NaN                      NaN
# 43                 NaN                     NaN                      NaN
# 44                 NaN                     NaN                      NaN
# 45                 NaN                     NaN                      NaN
# 46                 NaN                     NaN                      NaN
# 47                 NaN                     NaN                      NaN
# 48                 NaN                     NaN                      NaN
# 49                 NaN                     NaN                      NaN
#
#     c16_new_content_proportion  c16_len_quote  c16_len_original  \
# 0                          NaN            NaN               NaN
# 1                          NaN            NaN               NaN
# 2                          NaN            NaN               NaN
# 3                          NaN            NaN               NaN
# 4                          NaN            NaN               NaN
# 5                          NaN            NaN               NaN
# 6                          NaN            NaN               NaN
# 7                          NaN            NaN               NaN
# 8                          NaN            NaN               NaN
# 9                          NaN            NaN               NaN
# 10                         NaN            NaN               NaN
# 11                         NaN            NaN               NaN
# 12                         NaN            NaN               NaN
# 13                         NaN            NaN               NaN
# 14                         NaN            NaN               NaN
# 15                         NaN            NaN               NaN
# 16                         NaN            NaN               NaN
# 17                         NaN            NaN               NaN
# 18                         NaN            NaN               NaN
# 19                         NaN            NaN               NaN
# 20                         NaN            NaN               NaN
# 21                         NaN            NaN               NaN
# 22                         NaN            NaN               NaN
# 23                         NaN            NaN               NaN
# 24                         NaN            NaN               NaN
# 25                         NaN            NaN               NaN
# 26                         NaN            NaN               NaN
# 27                         NaN            NaN               NaN
# 28                         NaN            NaN               NaN
# 29                         NaN            NaN               NaN
# 30                         NaN            NaN               NaN
# 31                         NaN            NaN               NaN
# 32                         NaN            NaN               NaN
# 33                         1.0            0.0              81.0
# 34                         NaN            NaN               NaN
# 35                         NaN            NaN               NaN
# 36                         NaN            NaN               NaN
# 37                         NaN            NaN               NaN
# 38                         NaN            NaN               NaN
# 39                         NaN            NaN               NaN
# 40                         NaN            NaN               NaN
# 41                         NaN            NaN               NaN
# 42                         NaN            NaN               NaN
# 43                         NaN            NaN               NaN
# 44                         NaN            NaN               NaN
# 45                         NaN            NaN               NaN
# 46                         NaN            NaN               NaN
# 47                         NaN            NaN               NaN
# 48                         NaN            NaN               NaN
# 49                         NaN            NaN               NaN
#
#     c16_question_count
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 0.0
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 NaN
# 49                 NaN
#
# [50 rows x 97 columns]

# %%
features = [
    "lexical_similarity",
    "semantic_similarity",
    "new_content_proportion",
    "len_quote",
    "len_original",
    "question_count",
]
c_cols = [c for c in df.columns if c.startswith("c")]

# %%
def parse_col(col):
    m = re.match(r"c(\d+)_(.+)", col)
    return (int(m.group(1)), m.group(2)) if m else (None, None)

# %%
ordered_cols = ["filename"]
for feat in features:
    cols_for_feat = [c for c in c_cols if c.endswith(feat)]
    # sort by the numeric cN
    cols_for_feat = sorted(cols_for_feat, key=lambda c: parse_col(c)[0])
    ordered_cols.extend(cols_for_feat)

leftovers = [c for c in df.columns if c not in ordered_cols]
ordered_cols.extend(leftovers)

# %%
df = df[ordered_cols]

# %%
df
# Out:
#                                 filename  c1_lexical_similarity  \
# 0        113567594.0_1_delta_threads.xml               0.488401
# 1       1082495263.0_2_delta_threads.xml               0.516155
# 2       1409948101.0_2_delta_threads.xml               0.141375
# 3       1378810771.0_1_delta_threads.xml               0.495600
# 4       1437482501.0_1_delta_threads.xml               0.370636
# 5        154839924.0_4_delta_threads.xml               0.458793
# 6       1719432989.0_3_delta_threads.xml               0.365017
# 7       1719432989.0_1_delta_threads.xml               0.463852
# 8       1821161756.0_2_delta_threads.xml               0.496218
# 9       1821161756.0_1_delta_threads.xml               0.319614
# 10      2030191996.0_1_delta_threads.xml               0.139111
# 11       217468142.0_1_delta_threads.xml               0.111830
# 12       223614694.0_1_delta_threads.xml               0.542524
# 13       220698466.0_1_delta_threads.xml               0.450052
# 14      2366753957.0_5_delta_threads.xml               0.254624
# 15      2366753957.0_6_delta_threads.xml               0.584327
# 16      2366753957.0_4_delta_threads.xml               0.202238
# 17      2366753957.0_8_delta_threads.xml               0.181061
# 18      2512463257.0_1_delta_threads.xml               0.188947
# 19      2549309201.0_1_delta_threads.xml               0.529813
# 20       295203779.0_1_delta_threads.xml               0.122883
# 21       410977978.0_2_delta_threads.xml               0.221018
# 22       363480636.0_3_delta_threads.xml               0.095007
# 23       442068628.0_1_delta_threads.xml               0.421341
# 24       410977978.0_3_delta_threads.xml               0.221018
# 25   1075040167.0_2_deltaless_thread.xml               0.167597
# 26    113567594.0_4_deltaless_thread.xml               0.382178
# 27    115882088.0_2_deltaless_thread.xml               0.514537
# 28   1409948101.0_8_deltaless_thread.xml               0.528780
# 29  1437482501.0_91_deltaless_thread.xml               0.378414
# 30    144404372.0_8_deltaless_thread.xml               0.582748
# 31    154839924.0_3_deltaless_thread.xml               0.393170
# 32   1719432989.0_1_deltaless_thread.xml               0.198105
# 33    181959121.0_5_deltaless_thread.xml               0.400577
# 34   1821161756.0_9_deltaless_thread.xml               0.433579
# 35  1865427692.0_13_deltaless_thread.xml               0.218838
# 36  1865427692.0_24_deltaless_thread.xml               0.243087
# 37    217468142.0_3_deltaless_thread.xml               0.284283
# 38   2076541612.0_3_deltaless_thread.xml               0.541627
# 39    220698466.0_2_deltaless_thread.xml               0.484017
# 40  2242239967.0_10_deltaless_thread.xml               0.325564
# 41   2366753957.0_2_deltaless_thread.xml               0.253598
# 42   2547064804.0_7_deltaless_thread.xml               0.036432
# 43   2366753957.0_3_deltaless_thread.xml               0.311268
# 44  2676326580.0_26_deltaless_thread.xml               0.346060
# 45    401821196.0_2_deltaless_thread.xml               0.405395
# 46    363480636.0_5_deltaless_thread.xml               0.576405
# 47    410977978.0_3_deltaless_thread.xml               0.461033
# 48    410977978.0_4_deltaless_thread.xml               0.491018
# 49    442068628.0_4_deltaless_thread.xml               0.334885
#
#     c2_lexical_similarity  c3_lexical_similarity  c4_lexical_similarity  \
# 0                0.445649               0.375462               0.212708
# 1                0.319109               0.518953               0.553300
# 2                0.145488               0.053159               0.074178
# 3                0.245747               0.178331               0.179095
# 4                0.224723               0.330418               0.123331
# 5                0.404720               0.090714               0.074942
# 6                0.293389               0.264342               0.151523
# 7                0.847646               0.145630               0.243258
# 8                0.336253               0.105017               0.039874
# 9                0.058738               0.333366               0.269887
# 10               0.129397               0.289685               0.210373
# 11               0.132366               0.594351               0.272186
# 12               0.357501               0.165798               0.151299
# 13               0.311305               0.198947               0.060568
# 14               0.217338               0.214517               0.237616
# 15               0.246414               0.211424               0.056157
# 16               0.115605               0.310178               0.365713
# 17               0.171290               0.000000               0.000000
# 18               0.163504               0.361728               0.029398
# 19               0.113922               0.078745               0.136276
# 20               0.175786               0.000000               0.162290
# 21               0.162133               0.017162               0.076309
# 22               0.110578               0.127834               0.657270
# 23               0.267939               0.305585               0.363215
# 24               0.162133               0.149967               0.413817
# 25               0.124951               0.438407               0.290203
# 26               0.226192               0.228003               0.249863
# 27               0.046936               0.071483               0.139106
# 28               0.199306               0.152755               0.069841
# 29               0.267907               0.087824               0.294683
# 30               0.481498               0.556605               0.585534
# 31               0.185254               0.228512               0.191608
# 32               0.206137               0.169667               0.000000
# 33               0.211686               0.544919               0.093123
# 34               0.266250               0.093549               0.232967
# 35               0.213712               0.156095               0.065980
# 36               0.135956               0.270906               0.157629
# 37               0.183076               0.535518               0.111592
# 38               0.585000               0.233539               0.313266
# 39               0.577057               0.550286               0.594390
# 40               0.302696               0.610715               0.669671
# 41               0.052250               0.063355               0.076428
# 42               0.142044               0.151254               0.155511
# 43               0.086906               0.168657               0.154993
# 44               0.249358               0.077682               0.122683
# 45               0.204164               0.145663               0.349593
# 46               0.912388               0.744539               0.882088
# 47               0.394546               0.174897               0.108902
# 48               0.050883               0.068825               0.157204
# 49               0.257300               0.190960               0.207576
#
#     c5_lexical_similarity  c6_lexical_similarity  c7_lexical_similarity  \
# 0                0.230426               0.282581               0.188461
# 1                0.674431               0.183618               0.273141
# 2                0.276373               0.137113               0.510727
# 3                0.257632               0.049083               0.125001
# 4                0.075396               0.078745                    NaN
# 5                0.281379               0.477594               0.206816
# 6                0.311666               0.225627               0.214413
# 7                0.081223               0.331908               0.406744
# 8                0.120076               0.040936               0.040936
# 9                0.259431               0.067672               0.134662
# 10               0.301359               0.208702                    NaN
# 11               0.300493               0.183628               0.371424
# 12               0.463995               0.459092               0.222514
# 13               0.139538               0.249885               0.133796
# 14               0.220275               0.262685               0.275342
# 15               0.062211               0.086557               0.083117
# 16               0.221638               0.286253               0.121903
# 17               0.157335               0.086226               0.067436
# 18               0.072441               0.119137               0.056207
# 19               0.174164               0.434939               0.734757
# 20               0.145669               0.199668               0.204579
# 21               0.011460               0.067152               0.253399
# 22               0.265446               0.256459               0.123482
# 23               0.346846               0.314185               0.158890
# 24               0.076462               0.183713                    NaN
# 25               0.276064                    NaN                    NaN
# 26               0.211171                    NaN                    NaN
# 27               0.103682                    NaN                    NaN
# 28               0.046387                    NaN                    NaN
# 29               0.138675               0.321353               0.096683
# 30               0.240551               0.692145               0.135102
# 31               0.127557               0.183900               0.194749
# 32               0.112988               0.059522               0.072663
# 33               0.067582               0.256182               0.132793
# 34               0.135648               0.086549               0.000000
# 35               0.089439                    NaN                    NaN
# 36               0.089613               0.235265               0.261085
# 37               0.069170               0.103885               0.050457
# 38               0.209048               0.052878               0.150557
# 39               0.435776               0.338570               0.183273
# 40               0.619059                    NaN                    NaN
# 41               0.150640               0.044667               0.081738
# 42               0.068360               0.119315                    NaN
# 43               0.000000               0.449436               0.097629
# 44               0.047220               0.077348               0.120901
# 45               0.198448                    NaN                    NaN
# 46               0.674100               0.784748                    NaN
# 47               0.122088               0.255691               0.514013
# 48               0.068084                    NaN                    NaN
# 49               0.164137               0.074545               0.163630
#
#     c8_lexical_similarity  c9_lexical_similarity  ...  c7_question_count  \
# 0                0.217827                    NaN  ...                1.0
# 1                     NaN                    NaN  ...                0.0
# 2                     NaN                    NaN  ...                1.0
# 3                     NaN                    NaN  ...                4.0
# 4                     NaN                    NaN  ...                NaN
# 5                     NaN                    NaN  ...                0.0
# 6                0.215563               0.183693  ...                0.0
# 7                0.022549               0.487805  ...                1.0
# 8                     NaN                    NaN  ...                1.0
# 9                     NaN                    NaN  ...                1.0
# 10                    NaN                    NaN  ...                NaN
# 11               0.127318               0.016096  ...                2.0
# 12               0.220694               0.258160  ...                1.0
# 13               0.357520               0.521665  ...                0.0
# 14                    NaN                    NaN  ...                0.0
# 15               0.140311               0.056891  ...                0.0
# 16                    NaN                    NaN  ...                0.0
# 17               0.000000               0.000000  ...                0.0
# 18               0.067071               0.087310  ...                1.0
# 19               0.595100               0.722635  ...                2.0
# 20               0.301636               0.313040  ...                0.0
# 21               0.365175               0.018348  ...                0.0
# 22               0.125050               0.224110  ...                0.0
# 23                    NaN                    NaN  ...                0.0
# 24                    NaN                    NaN  ...                NaN
# 25                    NaN                    NaN  ...                NaN
# 26                    NaN                    NaN  ...                NaN
# 27                    NaN                    NaN  ...                NaN
# 28                    NaN                    NaN  ...                NaN
# 29               0.066702               0.307198  ...                0.0
# 30               0.186811               0.000000  ...                0.0
# 31               0.248530               0.323389  ...                0.0
# 32               0.030925               0.046179  ...                0.0
# 33               0.156219               0.071936  ...                1.0
# 34                    NaN                    NaN  ...                0.0
# 35                    NaN                    NaN  ...                NaN
# 36               0.624569                    NaN  ...                0.0
# 37               0.000000               0.000000  ...                0.0
# 38               0.093093               0.122227  ...                0.0
# 39               0.226306                    NaN  ...                0.0
# 40                    NaN                    NaN  ...                NaN
# 41               0.092089               0.195213  ...                1.0
# 42                    NaN                    NaN  ...                NaN
# 43               0.064805               0.000000  ...                1.0
# 44                    NaN                    NaN  ...                1.0
# 45                    NaN                    NaN  ...                NaN
# 46                    NaN                    NaN  ...                NaN
# 47                    NaN                    NaN  ...                0.0
# 48                    NaN                    NaN  ...                NaN
# 49               0.132951                    NaN  ...                0.0
#
#     c8_question_count  c9_question_count  c10_question_count  \
# 0                 0.0                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
# 5                 NaN                NaN                 NaN
# 6                 0.0                0.0                 NaN
# 7                 0.0                1.0                 0.0
# 8                 NaN                NaN                 NaN
# 9                 NaN                NaN                 NaN
# 10                NaN                NaN                 NaN
# 11                0.0                0.0                 0.0
# 12                1.0                0.0                 2.0
# 13                1.0                0.0                 2.0
# 14                NaN                NaN                 NaN
# 15                0.0                0.0                 NaN
# 16                NaN                NaN                 NaN
# 17                0.0                0.0                 0.0
# 18                0.0                0.0                 0.0
# 19                0.0                1.0                 3.0
# 20                0.0                1.0                 NaN
# 21                0.0                1.0                 0.0
# 22                1.0                0.0                 0.0
# 23                NaN                NaN                 NaN
# 24                NaN                NaN                 NaN
# 25                NaN                NaN                 NaN
# 26                NaN                NaN                 NaN
# 27                NaN                NaN                 NaN
# 28                NaN                NaN                 NaN
# 29                0.0                0.0                 NaN
# 30                1.0                0.0                 0.0
# 31                2.0                0.0                 1.0
# 32                0.0                1.0                 NaN
# 33                0.0                2.0                 0.0
# 34                NaN                NaN                 NaN
# 35                NaN                NaN                 NaN
# 36                1.0                NaN                 NaN
# 37                0.0                0.0                 1.0
# 38                0.0                0.0                 2.0
# 39                0.0                NaN                 NaN
# 40                NaN                NaN                 NaN
# 41                1.0                0.0                 0.0
# 42                NaN                NaN                 NaN
# 43                0.0                0.0                 NaN
# 44                NaN                NaN                 NaN
# 45                NaN                NaN                 NaN
# 46                NaN                NaN                 NaN
# 47                NaN                NaN                 NaN
# 48                NaN                NaN                 NaN
# 49                0.0                NaN                 NaN
#
#     c11_question_count  c12_question_count  c13_question_count  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  1.0                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 0.0                 1.0                 0.0
# 12                 3.0                 0.0                 3.0
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 1.0                 1.0                 1.0
# 18                 1.0                 0.0                 0.0
# 19                 2.0                 2.0                 2.0
# 20                 NaN                 NaN                 NaN
# 21                 0.0                 NaN                 NaN
# 22                 2.0                 0.0                 0.0
# 23                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 25                 NaN                 NaN                 NaN
# 26                 NaN                 NaN                 NaN
# 27                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 29                 NaN                 NaN                 NaN
# 30                 0.0                 NaN                 NaN
# 31                 0.0                 0.0                 NaN
# 32                 NaN                 NaN                 NaN
# 33                 0.0                 0.0                 1.0
# 34                 NaN                 NaN                 NaN
# 35                 NaN                 NaN                 NaN
# 36                 NaN                 NaN                 NaN
# 37                 0.0                 NaN                 NaN
# 38                 0.0                 0.0                 3.0
# 39                 NaN                 NaN                 NaN
# 40                 NaN                 NaN                 NaN
# 41                 NaN                 NaN                 NaN
# 42                 NaN                 NaN                 NaN
# 43                 NaN                 NaN                 NaN
# 44                 NaN                 NaN                 NaN
# 45                 NaN                 NaN                 NaN
# 46                 NaN                 NaN                 NaN
# 47                 NaN                 NaN                 NaN
# 48                 NaN                 NaN                 NaN
# 49                 NaN                 NaN                 NaN
#
#     c14_question_count  c15_question_count  c16_question_count
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 0.0                 1.0                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 0.0                 0.0                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 1.0                 1.0                 NaN
# 23                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 25                 NaN                 NaN                 NaN
# 26                 NaN                 NaN                 NaN
# 27                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 29                 NaN                 NaN                 NaN
# 30                 NaN                 NaN                 NaN
# 31                 NaN                 NaN                 NaN
# 32                 NaN                 NaN                 NaN
# 33                 0.0                 0.0                 0.0
# 34                 NaN                 NaN                 NaN
# 35                 NaN                 NaN                 NaN
# 36                 NaN                 NaN                 NaN
# 37                 NaN                 NaN                 NaN
# 38                 0.0                 NaN                 NaN
# 39                 NaN                 NaN                 NaN
# 40                 NaN                 NaN                 NaN
# 41                 NaN                 NaN                 NaN
# 42                 NaN                 NaN                 NaN
# 43                 NaN                 NaN                 NaN
# 44                 NaN                 NaN                 NaN
# 45                 NaN                 NaN                 NaN
# 46                 NaN                 NaN                 NaN
# 47                 NaN                 NaN                 NaN
# 48                 NaN                 NaN                 NaN
# 49                 NaN                 NaN                 NaN
#
# [50 rows x 97 columns]

# %%
df.to_csv(f"{cwd}/97_op_nlp.csv", index=False)
