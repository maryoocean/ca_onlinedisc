# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
import glob
import json
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## file parsing (op + 5 comments in a list)

# %%
"""
STOPWORDS = set(stopwords.words("english"))

def clean_text(text, STOPWORDS):
  text = text.lower()
  text1 = re.sub(r'http\S+|www\.\S+', '', text)
  text1 = re.sub(r'u\/\w+|r\/\w+', '', text1)
  tokens = [word for word in text1.split() if word.isalpha() and word not in STOPWORDS]
  text1 = " ".join(tokens)
  if len(text1) > 1:
    return text1
  else:
    return text
"""

# %%
def clean_text(text):
  text = text.lower()
  text = re.sub(r'http\S+|www\.\S+', '', text)
  text = re.sub(r'u\/\w+|r\/\w+', '', text)
  return text

# %%
def process_thread(xml_content, filename):
    soup = BeautifulSoup(xml_content, features="xml")
    submission = soup.find('submission')
    original_post = submission.find('original_post').text.strip()
    original_post = clean_text(original_post)
    op_user = submission.find('original_poster').text.strip() if submission.find('original_poster') else "unknown_op"

    user_map = {'op': op_user}

    comments = soup.find_all('comment')
    comment_texts = []
    for i, comment in enumerate(comments):
      text = comment.find('text').text.strip()
      text = clean_text(text)
      user = comment.get('user', f'user_{i}')
      comment_texts.append(text)
      user_map[f"comment_{i+1}"] = user

    comment_texts.insert(0, original_post)
    json_line = {"filename": filename,
                 "unique_users": len(set(user_map.values())),
                 "users": user_map}

    return original_post, comment_texts, json_line

# %% [markdown]
# # emotion pipeline

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch
from tqdm import tqdm

# %%
model_name = "tae898/emoberta-large"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.model_max_length = 512
device = 0 if torch.cuda.is_available() else -1
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/408 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
torch.cuda.is_available()
# Out:
# True

# %%
emotion_pipeline = pipeline("text-classification", model=model,
                            tokenizer=tokenizer, return_all_scores=True,
                            top_k=None, device=device)
# Out:
# Device set to use cuda:0

# %% [markdown]
# # pipeline execution

# %%
def analyze_reddit_thread(comments, row_data):
    results = []

    for i, comment in enumerate(comments, 1):

      c_name = 'op' if i == 1 else f"c{i-1}"

      emotion_scores = emotion_pipeline(comment, truncation=True,
                                        padding='max_length', max_length=512)[0]

      top_emotion = max(emotion_scores, key=lambda x: x['score'])
      row_data[f'{c_name}_main'] = top_emotion['label']
      #row_data[f'{c_name}_confidence'] = round(top_emotion['score'], 3)

      for item in emotion_scores:
        label = item['label']
        score = round(item['score'], 3)
        row_data[f'{c_name}_{label}'] = score

    return pd.DataFrame([row_data])

# %%
cwd = os.getcwd()

# %%
input_dir = f"{cwd}/100_sample/"
xml_files = glob.glob(os.path.join(input_dir, "*.xml"))
emo_df = pd.DataFrame()
jsonl_output = f"{cwd}/users.jsonl"

for file in tqdm(xml_files):
  if file.split('/')[-1] in filenames:
    with open(file, 'r', encoding='utf-8') as f:
      xml_content = f.read()
      filename = os.path.basename(file)
      op, comms, json_line = process_thread(xml_content, filename)
      # print(op, comms, json_line)
    with open(jsonl_output, 'a', encoding="utf-8") as f:
      f.write(json.dumps(json_line) + "\n")
    try:
      row_data = {'filename': filename}
      emo_scores = analyze_reddit_thread(comms, row_data)
      emo_df = pd.concat([emo_df, emo_scores], ignore_index=True)
    except Exception as e:
      print(f" CRASHED on comment {i}")
      print(e)
# Out:
# 100%|██████████| 97/97 [01:44<00:00,  1.07s/it]

# %%
emo_df['outcome'] = emo_df['filename'].apply(lambda x: 0 if 'deltaless' in str(x) else 1)
# Out:
# /tmp/ipython-input-2345249967.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   emo_df['outcome'] = emo_df['filename'].apply(lambda x: 0 if 'deltaless' in str(x) else 1)

# %%
emo_df
# Out:
#                                 filename  op_main  op_anger  op_sadness  \
# 0        113567594.0_1_delta_threads.xml    anger     0.686       0.220
# 1       1082495263.0_2_delta_threads.xml    anger     0.619       0.068
# 2       1409948101.0_2_delta_threads.xml  neutral     0.160       0.018
# 3       1378810771.0_1_delta_threads.xml    anger     0.523       0.168
# 4       1437482501.0_1_delta_threads.xml  neutral     0.319       0.068
# 5        154839924.0_4_delta_threads.xml  neutral     0.045       0.009
# 6       1719432989.0_3_delta_threads.xml  neutral     0.259       0.026
# 7       1719432989.0_1_delta_threads.xml  neutral     0.259       0.026
# 8       1821161756.0_2_delta_threads.xml    anger     0.697       0.045
# 9       1821161756.0_1_delta_threads.xml    anger     0.697       0.045
# 10      2030191996.0_1_delta_threads.xml  neutral     0.107       0.079
# 11       217468142.0_1_delta_threads.xml    anger     0.788       0.011
# 12       223614694.0_1_delta_threads.xml  neutral     0.310       0.019
# 13       220698466.0_1_delta_threads.xml  neutral     0.411       0.051
# 14      2366753957.0_5_delta_threads.xml  neutral     0.036       0.011
# 15      2366753957.0_6_delta_threads.xml  neutral     0.036       0.011
# 16      2366753957.0_4_delta_threads.xml  neutral     0.036       0.011
# 17      2366753957.0_8_delta_threads.xml  neutral     0.036       0.011
# 18      2512463257.0_1_delta_threads.xml    anger     0.648       0.016
# 19      2549309201.0_1_delta_threads.xml    anger     0.743       0.011
# 20       295203779.0_1_delta_threads.xml  neutral     0.134       0.012
# 21       410977978.0_2_delta_threads.xml    anger     0.814       0.049
# 22       363480636.0_3_delta_threads.xml  neutral     0.090       0.012
# 23       442068628.0_1_delta_threads.xml    anger     0.601       0.184
# 24       410977978.0_3_delta_threads.xml    anger     0.814       0.049
# 25   1075040167.0_2_deltaless_thread.xml  neutral     0.280       0.090
# 26    113567594.0_4_deltaless_thread.xml    anger     0.686       0.220
# 27    115882088.0_2_deltaless_thread.xml  neutral     0.105       0.015
# 28   1409948101.0_8_deltaless_thread.xml  neutral     0.160       0.018
# 29  1437482501.0_91_deltaless_thread.xml  neutral     0.319       0.068
# 30    144404372.0_8_deltaless_thread.xml  neutral     0.265       0.054
# 31    154839924.0_3_deltaless_thread.xml  neutral     0.045       0.009
# 32   1719432989.0_1_deltaless_thread.xml  neutral     0.259       0.026
# 33    181959121.0_5_deltaless_thread.xml    anger     0.657       0.035
# 34   1821161756.0_9_deltaless_thread.xml    anger     0.697       0.045
# 35  1865427692.0_13_deltaless_thread.xml    anger     0.553       0.049
# 36  1865427692.0_24_deltaless_thread.xml    anger     0.553       0.049
# 37    217468142.0_3_deltaless_thread.xml    anger     0.788       0.011
# 38   2076541612.0_3_deltaless_thread.xml  neutral     0.022       0.010
# 39    220698466.0_2_deltaless_thread.xml  neutral     0.411       0.051
# 40  2242239967.0_10_deltaless_thread.xml  neutral     0.147       0.035
# 41   2366753957.0_2_deltaless_thread.xml  neutral     0.036       0.011
# 42   2547064804.0_7_deltaless_thread.xml  neutral     0.149       0.181
# 43   2366753957.0_3_deltaless_thread.xml  neutral     0.036       0.011
# 44  2676326580.0_26_deltaless_thread.xml    anger     0.605       0.095
# 45    401821196.0_2_deltaless_thread.xml  neutral     0.107       0.071
# 46    363480636.0_5_deltaless_thread.xml  neutral     0.090       0.012
# 47    410977978.0_3_deltaless_thread.xml    anger     0.814       0.049
# 48    410977978.0_4_deltaless_thread.xml    anger     0.814       0.049
# 49    442068628.0_4_deltaless_thread.xml    anger     0.601       0.184
#
#     op_neutral  op_joy  op_disgust  op_fear  op_surprise  c1_main  ...  \
# 0        0.053   0.029       0.006    0.004        0.002  neutral  ...
# 1        0.236   0.056       0.012    0.007        0.002    anger  ...
# 2        0.740   0.068       0.012    0.002        0.001  neutral  ...
# 3        0.169   0.086       0.049    0.003        0.002    anger  ...
# 4        0.408   0.150       0.045    0.007        0.002  neutral  ...
# 5        0.603   0.340       0.001    0.001        0.001  neutral  ...
# 6        0.583   0.110       0.014    0.005        0.002    anger  ...
# 7        0.583   0.110       0.014    0.005        0.002    anger  ...
# 8        0.078   0.058       0.116    0.003        0.004    anger  ...
# 9        0.078   0.058       0.116    0.003        0.004    anger  ...
# 10       0.762   0.044       0.005    0.001        0.001  neutral  ...
# 11       0.098   0.084       0.015    0.002        0.002  neutral  ...
# 12       0.597   0.062       0.007    0.003        0.001  neutral  ...
# 13       0.463   0.069       0.003    0.003        0.001  neutral  ...
# 14       0.911   0.037       0.003    0.001        0.001    anger  ...
# 15       0.911   0.037       0.003    0.001        0.001  neutral  ...
# 16       0.911   0.037       0.003    0.001        0.001  neutral  ...
# 17       0.911   0.037       0.003    0.001        0.001  neutral  ...
# 18       0.236   0.084       0.013    0.001        0.001  neutral  ...
# 19       0.159   0.072       0.011    0.002        0.002    anger  ...
# 20       0.755   0.095       0.002    0.001        0.001  sadness  ...
# 21       0.011   0.097       0.022    0.003        0.003  neutral  ...
# 22       0.727   0.165       0.003    0.001        0.001  sadness  ...
# 23       0.159   0.047       0.004    0.003        0.001  neutral  ...
# 24       0.011   0.097       0.022    0.003        0.003  neutral  ...
# 25       0.359   0.059       0.193    0.017        0.003  neutral  ...
# 26       0.053   0.029       0.006    0.004        0.002  neutral  ...
# 27       0.830   0.044       0.004    0.002        0.001  neutral  ...
# 28       0.740   0.068       0.012    0.002        0.001  neutral  ...
# 29       0.408   0.150       0.045    0.007        0.002      joy  ...
# 30       0.603   0.068       0.005    0.003        0.002    anger  ...
# 31       0.603   0.340       0.001    0.001        0.001  neutral  ...
# 32       0.583   0.110       0.014    0.005        0.002  neutral  ...
# 33       0.182   0.119       0.005    0.001        0.001  neutral  ...
# 34       0.078   0.058       0.116    0.003        0.004  neutral  ...
# 35       0.320   0.060       0.014    0.003        0.002  neutral  ...
# 36       0.320   0.060       0.014    0.003        0.002    anger  ...
# 37       0.098   0.084       0.015    0.002        0.002  neutral  ...
# 38       0.908   0.057       0.001    0.001        0.001  neutral  ...
# 39       0.463   0.069       0.003    0.003        0.001    anger  ...
# 40       0.784   0.029       0.002    0.002        0.001  neutral  ...
# 41       0.911   0.037       0.003    0.001        0.001  neutral  ...
# 42       0.533   0.114       0.017    0.004        0.002  neutral  ...
# 43       0.911   0.037       0.003    0.001        0.001  neutral  ...
# 44       0.217   0.066       0.012    0.003        0.001  neutral  ...
# 45       0.647   0.166       0.004    0.003        0.002  neutral  ...
# 46       0.727   0.165       0.003    0.001        0.001    anger  ...
# 47       0.011   0.097       0.022    0.003        0.003  neutral  ...
# 48       0.011   0.097       0.022    0.003        0.003    anger  ...
# 49       0.159   0.047       0.004    0.003        0.001  neutral  ...
#
#     c15_disgust  c16_main  c16_neutral  c16_anger  c16_joy  c16_sadness  \
# 0           NaN       NaN          NaN        NaN      NaN          NaN
# 1           NaN       NaN          NaN        NaN      NaN          NaN
# 2           NaN       NaN          NaN        NaN      NaN          NaN
# 3           NaN       NaN          NaN        NaN      NaN          NaN
# 4           NaN       NaN          NaN        NaN      NaN          NaN
# 5           NaN       NaN          NaN        NaN      NaN          NaN
# 6           NaN       NaN          NaN        NaN      NaN          NaN
# 7           NaN       NaN          NaN        NaN      NaN          NaN
# 8           NaN       NaN          NaN        NaN      NaN          NaN
# 9           NaN       NaN          NaN        NaN      NaN          NaN
# 10          NaN       NaN          NaN        NaN      NaN          NaN
# 11          NaN       NaN          NaN        NaN      NaN          NaN
# 12          NaN       NaN          NaN        NaN      NaN          NaN
# 13          NaN       NaN          NaN        NaN      NaN          NaN
# 14          NaN       NaN          NaN        NaN      NaN          NaN
# 15          NaN       NaN          NaN        NaN      NaN          NaN
# 16          NaN       NaN          NaN        NaN      NaN          NaN
# 17        0.004       NaN          NaN        NaN      NaN          NaN
# 18          NaN       NaN          NaN        NaN      NaN          NaN
# 19        0.006       NaN          NaN        NaN      NaN          NaN
# 20          NaN       NaN          NaN        NaN      NaN          NaN
# 21          NaN       NaN          NaN        NaN      NaN          NaN
# 22        0.008       NaN          NaN        NaN      NaN          NaN
# 23          NaN       NaN          NaN        NaN      NaN          NaN
# 24          NaN       NaN          NaN        NaN      NaN          NaN
# 25          NaN       NaN          NaN        NaN      NaN          NaN
# 26          NaN       NaN          NaN        NaN      NaN          NaN
# 27          NaN       NaN          NaN        NaN      NaN          NaN
# 28          NaN       NaN          NaN        NaN      NaN          NaN
# 29          NaN       NaN          NaN        NaN      NaN          NaN
# 30          NaN       NaN          NaN        NaN      NaN          NaN
# 31          NaN       NaN          NaN        NaN      NaN          NaN
# 32          NaN       NaN          NaN        NaN      NaN          NaN
# 33        0.031   neutral        0.481      0.294    0.156        0.033
# 34          NaN       NaN          NaN        NaN      NaN          NaN
# 35          NaN       NaN          NaN        NaN      NaN          NaN
# 36          NaN       NaN          NaN        NaN      NaN          NaN
# 37          NaN       NaN          NaN        NaN      NaN          NaN
# 38          NaN       NaN          NaN        NaN      NaN          NaN
# 39          NaN       NaN          NaN        NaN      NaN          NaN
# 40          NaN       NaN          NaN        NaN      NaN          NaN
# 41          NaN       NaN          NaN        NaN      NaN          NaN
# 42          NaN       NaN          NaN        NaN      NaN          NaN
# 43          NaN       NaN          NaN        NaN      NaN          NaN
# 44          NaN       NaN          NaN        NaN      NaN          NaN
# 45          NaN       NaN          NaN        NaN      NaN          NaN
# 46          NaN       NaN          NaN        NaN      NaN          NaN
# 47          NaN       NaN          NaN        NaN      NaN          NaN
# 48          NaN       NaN          NaN        NaN      NaN          NaN
# 49          NaN       NaN          NaN        NaN      NaN          NaN
#
#     c16_disgust c16_fear  c16_surprise  outcome
# 0           NaN      NaN           NaN        1
# 1           NaN      NaN           NaN        1
# 2           NaN      NaN           NaN        1
# 3           NaN      NaN           NaN        1
# 4           NaN      NaN           NaN        1
# 5           NaN      NaN           NaN        1
# 6           NaN      NaN           NaN        1
# 7           NaN      NaN           NaN        1
# 8           NaN      NaN           NaN        1
# 9           NaN      NaN           NaN        1
# 10          NaN      NaN           NaN        1
# 11          NaN      NaN           NaN        1
# 12          NaN      NaN           NaN        1
# 13          NaN      NaN           NaN        1
# 14          NaN      NaN           NaN        1
# 15          NaN      NaN           NaN        1
# 16          NaN      NaN           NaN        1
# 17          NaN      NaN           NaN        1
# 18          NaN      NaN           NaN        1
# 19          NaN      NaN           NaN        1
# 20          NaN      NaN           NaN        1
# 21          NaN      NaN           NaN        1
# 22          NaN      NaN           NaN        1
# 23          NaN      NaN           NaN        1
# 24          NaN      NaN           NaN        1
# 25          NaN      NaN           NaN        0
# 26          NaN      NaN           NaN        0
# 27          NaN      NaN           NaN        0
# 28          NaN      NaN           NaN        0
# 29          NaN      NaN           NaN        0
# 30          NaN      NaN           NaN        0
# 31          NaN      NaN           NaN        0
# 32          NaN      NaN           NaN        0
# 33        0.031    0.003         0.002        0
# 34          NaN      NaN           NaN        0
# 35          NaN      NaN           NaN        0
# 36          NaN      NaN           NaN        0
# 37          NaN      NaN           NaN        0
# 38          NaN      NaN           NaN        0
# 39          NaN      NaN           NaN        0
# 40          NaN      NaN           NaN        0
# 41          NaN      NaN           NaN        0
# 42          NaN      NaN           NaN        0
# 43          NaN      NaN           NaN        0
# 44          NaN      NaN           NaN        0
# 45          NaN      NaN           NaN        0
# 46          NaN      NaN           NaN        0
# 47          NaN      NaN           NaN        0
# 48          NaN      NaN           NaN        0
# 49          NaN      NaN           NaN        0
#
# [50 rows x 138 columns]

# %%
file_path = f'{cwd}/97_emo_scores.csv'

# %%
emo_df.to_csv(file_path, index=False)

# %%
emo_df.head()
# Out:
#                            filename  op_main  op_neutral  op_anger  op_joy  \
# 0  1062071645.0_1_delta_threads.xml  neutral       0.500     0.305   0.167
# 1  1075040167.0_1_delta_threads.xml    anger       0.078     0.616   0.058
# 2   115882088.0_1_delta_threads.xml  neutral       0.716     0.153   0.086
# 3  1102614149.0_2_delta_threads.xml  neutral       0.598     0.244   0.098
# 4   134214340.0_1_delta_threads.xml  neutral       0.465     0.167   0.330
#
#    op_sadness  op_disgust  op_surprise  op_fear  c1_main  ...  c19_fear  \
# 0       0.019       0.005        0.003    0.002    anger  ...       NaN
# 1       0.082       0.130        0.018    0.019    anger  ...       NaN
# 2       0.015       0.019        0.003    0.009  neutral  ...       NaN
# 3       0.052       0.003        0.002    0.004  neutral  ...       NaN
# 4       0.027       0.003        0.003    0.004    anger  ...       NaN
#
#    c20_main  c20_anger  c20_neutral  c20_joy  c20_sadness  c20_disgust  \
# 0       NaN        NaN          NaN      NaN          NaN          NaN
# 1       NaN        NaN          NaN      NaN          NaN          NaN
# 2       NaN        NaN          NaN      NaN          NaN          NaN
# 3       NaN        NaN          NaN      NaN          NaN          NaN
# 4       NaN        NaN          NaN      NaN          NaN          NaN
#
#   c20_surprise  c20_fear  outcome
# 0          NaN       NaN        1
# 1          NaN       NaN        1
# 2          NaN       NaN        1
# 3          NaN       NaN        1
# 4          NaN       NaN        1
#
# [5 rows x 170 columns]
