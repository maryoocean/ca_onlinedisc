# %% [markdown]
# ## imports

# %%
import pandas as pd
import json
import re
from tqdm import tqdm

# %%
# for file parsing

from bs4 import BeautifulSoup
import os
import glob

# %% [markdown]
# ## install llm and .env

# %%
pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.64.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# Downloading anthropic-0.64.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.2/297.2 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.64.0

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.1.1)

# %%
import anthropic
import json
import time

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
client = anthropic.Anthropic(
    api_key=os.getenv('ANTHROPIC_API_KEY'),
)

# %% [markdown]
# ## file parsing

# %%
def process_thread(xml_content: str):
  soup = BeautifulSoup(xml_content, features="xml")
  submission = soup.find('submission')

  op_user = submission.find('original_poster').text.strip()
  op_text = submission.find('original_post').text.strip()
  original_post = f'<original_post user="{op_user}">{op_text}</original_post>'


  comments_text = soup.find_all('comment')

  comments = ""
  for idx, comment in enumerate(comments_text, start=1):
      user = comment.get('user', 'unknown')
      text_elem = comment.find('text')
      text = text_elem.text.strip() if text_elem else ""
      comments += f'<comment idx={idx} user="{user}">{text}</comment>\n'

  return original_post, comments

# %% [markdown]
# ## JSONL file for batch-processing (i.e. creating a set of API calls to submit at once to openAI)

# %% [markdown]
# I am pre-processing XML files to submit them as a string of the kind:
#
# ```
# <original_post>...</original_post>\n\n
# <comment idx=1 user=name1>...</comment>\n
# <comment idx=2 user=name2>...</comment>\n
# ...
# <comment idx=5 user=name3>...</comment>\n
# ```
#
# Thus hiding from LLM unnecessary noise not to interfere with the results (e.g. delta information, or user name) and to improve efficiency (bc of lower number of tokens to process).
#
# I will be requesting evaluation for the first 5 comments in the thread. That is because 5 is the lowest number of comments in the sample. Going up would force N/A values in the resulting dataset, and it would create more complications.

# %%
from anthropic.types.message_create_params import MessageCreateParamsNonStreaming
from anthropic.types.messages.batch_create_params import Request

# %%
instructions = """
You are a moderator with expertise in linguistics. You will receive a conversation thread - a parsed XML file with the following tags:
* <filename>: ID of the conversation
* <original_post>: Original post content
* <comment>: Chronologically ordered first five comments

## Task
Write a short summary capturing the trajectory of an online conversation, turn by turn.

## Requirements
- Do not include specific topics, claims, or arguments from the conversation
- Include no more than 1 sentence describing the impact of each turn
- The overall number of sentences in your output should not exceed 6
- Focus on conversational dynamics, not content

## Style to Avoid
Example of what NOT to do:
"Speaker1, who is Asian, defended Asians and pointed out that a study found that whites, Hispanics, and blacks were accepted into universities in that order, with Asians being accepted the least. Speaker2 acknowledged that Asians have high household income, but argued that this could be a plausible explanation for the study's findings. Speaker1 disagreed and stated that the study did not take wealth into consideration."

This style mentions specific claims and topics, which are not needed.

## Style to Follow
Do include:
- Sentiment indicators (e.g., sarcasm, passive-aggressive, polite, frustration, attack, blame)
- Individual intentions (e.g., agreement, disagreement, persistent-agreement, persistent-disagreement, rebuttal, defense, concession, confusion, clarification, neutral, accusation)
- Conversational strategies (e.g., rhetorical questions, straw man fallacy, identifying fallacies, appealing to emotions)

Examples of correct style:

Example 1: "Both speakers have differing opinions and appeared defensive. Speaker1 attacks Speaker2 by diminishing the importance of his argument and Speaker2 blames Speaker1 for using profane words. Both speakers accuse each other of being overly judgmental of their personal qualities rather than arguments."

Example 2: "The two speakers refuted each other with back-and-forth accusations. Throughout the conversation, they kept harshly fault-finding with overly critical viewpoints, creating an intense and inefficient discussion."

Example 3: "Speaker1 attacks Speaker2 by questioning the relevance of his premise and Speaker2 blames Speaker1 for using profane words. Both speakers accuse each other of being overly judgmental of their personal qualities rather than arguments."

## Focus Areas
The trajectory summary should capture the moments where the tension of the conversation notably changes.

## Complete Example
Trajectory summary:
Four speakers express their different points of view subsequently, building off of each other's arguments. Speaker1 disagrees with a specific point from Speaker2's argument, triggering Speaker2 to contradict Speaker1 in response. Then, Speaker3 jumps into the conversation to support Speaker1's argument, which leads Speaker2 to adamantly defend their argument. Speaker2 then quotes a deleted comment, giving an extensive counterargument. The overall tone remains civil.

Now, provide the trajectory summary for the following conversation.
"""

# %%
def prepare_batch_line(file, original_post, comments, instructions, i):
  conversation_text = f"<filaname>{file}</filename>\n<original_post>{original_post}</original_post>\n\n{comments}"
  system_prompt = instructions

  request = Request(
        custom_id=f"request-{i}",
        params=MessageCreateParamsNonStreaming(
            model="claude-opus-4-20250514",
            max_tokens=1024,
            system=[{
                "type": "text",
                "text": instructions,
                "cache_control": {"type": "ephemeral"}
                }],
            messages=[{
                "role": "user",
                "content": conversation_text
                }],
            temperature=0
        )
    )

  return request

# %%
def run_summary(parsed_content, instructions):

    response = client.messages.create(
        model="claude-opus-4-20250514",
        max_tokens=2048,
        temperature=0,
        system=[{
                "type": "text",
                "text": instructions,
                "cache_control": {"type": "ephemeral"}
                }],
            messages=[{
                "role": "user",
                "content": parsed_content
                }],
    )

    return response.content[0].text.strip()

# %%
input_dir = f"{cwd}/100_sample/"
xml_files = glob.glob(os.path.join(input_dir, "*.xml"))
xml_dict = {}
decision_dict = {}
batch_lines = []

for i, file in enumerate(xml_files, 1):
  with open(file, 'r', encoding='utf-8') as f:
    xml_content = f.read()
    op, comms = process_thread(xml_content)
    fn = os.path.basename(file)

  req = prepare_batch_line(fn, op, comms, instructions, i)
  decision_dict[f'request-{i}'] = fn
  batch_lines.append(req)

# %%
print(len(batch_lines))
# Out:
# 97

# %%
requests = []
for r in batch_lines:
  requests.append(r)

# %%
message_batch = client.messages.batches.create(requests=requests)
print(message_batch)

# %%
mbatch_id = message_batch.id

# %%
message_batch = client.messages.batches.retrieve(
    mbatch_id,
)

print(message_batch)

# %% [markdown]
# ### processing batch output (JSONL -> df)

# %%
import json

records = []

for result in client.messages.batches.results(mbatch_id):
    custom_id = result.custom_id

    text_blocks = result.result.message.content
    content_str = "".join(block.text for block in text_blocks if block.type == "text")


    # flatten nested JSON
    flattened = {'custom_id': custom_id,
                 'response': content_str}

    records.append(flattened)

# %%
resp_df = pd.DataFrame(records)

# %%
print(resp_df.head())
# Out:
#    custom_id                                           response
# 0  request-1  Trajectory summary:\nThe original poster prese...
# 1  request-2  Trajectory summary:\nThe conversation begins w...
# 2  request-3  Trajectory summary:\nThe original poster prese...
# 3  request-4  Trajectory summary:\nThe original poster prese...
# 4  request-5  Trajectory summary:\nThe original poster prese...

# %%
decisions_files = pd.DataFrame(list(decision_dict.items()), columns=["custom_id", "filename"])

# %%
resp_merged = resp_df.merge(decisions_files, on="custom_id", how="left")

# %%
resp_merged
# Out:
#      custom_id                                           response  \
# 0    request-1  Trajectory summary:\nThe original poster prese...
# 1    request-2  Trajectory summary:\nThe conversation begins w...
# 2    request-3  Trajectory summary:\nThe original poster prese...
# 3    request-4  Trajectory summary:\nThe original poster prese...
# 4    request-5  Trajectory summary:\nThe original poster prese...
# ..         ...                                                ...
# 92  request-93  Trajectory summary:\nThe original poster prese...
# 93  request-94  Trajectory summary:\nThe original poster expre...
# 94  request-95  Trajectory summary:\nThe original poster expre...
# 95  request-96  Trajectory summary:\nThe original poster expre...
# 96  request-97  Looking at this conversation thread, here's th...
#
#                               filename
# 0     1062071645.0_1_delta_threads.xml
# 1     1075040167.0_1_delta_threads.xml
# 2      115882088.0_1_delta_threads.xml
# 3      113567594.0_1_delta_threads.xml
# 4     1082495263.0_2_delta_threads.xml
# ..                                 ...
# 92  363480636.0_3_deltaless_thread.xml
# 93  410977978.0_3_deltaless_thread.xml
# 94  410977978.0_4_deltaless_thread.xml
# 95  442068628.0_4_deltaless_thread.xml
# 96  444945722.0_1_deltaless_thread.xml
#
# [97 rows x 3 columns]

# %%
resp_merged["response"] = resp_merged["response"].str.replace("Trajectory summary:\n", "", regex=False)

# %%
resp_merged
# Out:
#      custom_id                                           response  \
# 0    request-1  The original poster presents a critical view b...
# 1    request-2  The conversation begins with Speaker1 presenti...
# 2    request-3  The original poster presents a defense of farm...
# 3    request-4  The original poster presents a pessimistic vie...
# 4    request-5  The original poster presents a concern about p...
# ..         ...                                                ...
# 92  request-93  The original poster presents a controversial p...
# 93  request-94  The original poster expresses extreme frustrat...
# 94  request-95  The original poster expresses extreme frustrat...
# 95  request-96  The original poster expresses deep pessimism a...
# 96  request-97  Looking at this conversation thread, here's th...
#
#                               filename
# 0     1062071645.0_1_delta_threads.xml
# 1     1075040167.0_1_delta_threads.xml
# 2      115882088.0_1_delta_threads.xml
# 3      113567594.0_1_delta_threads.xml
# 4     1082495263.0_2_delta_threads.xml
# ..                                 ...
# 92  363480636.0_3_deltaless_thread.xml
# 93  410977978.0_3_deltaless_thread.xml
# 94  410977978.0_4_deltaless_thread.xml
# 95  442068628.0_4_deltaless_thread.xml
# 96  444945722.0_1_deltaless_thread.xml
#
# [97 rows x 3 columns]

# %%
def count_sentences(text):
    sentences = re.split(r'[.!?](?:\s|$)', text)
    sentences = [s.strip() for s in sentences if s.strip()]
    return len(sentences)

resp_merged["sentence_count"] = resp_merged["response"].apply(count_sentences)

# %%
resp_merged['outcome'] = resp_merged['filename'].apply(lambda x: 0 if 'deltaless' in str(x) else 1)

# %%
resp_merged.to_csv(f'{cwd}/97_claude_summaries.csv')

# %%
df = pd.DataFrame(list(xml_dict.items()), columns=["filename", "summaries"])

# %%
df["summaries"] = df["summaries"].str.replace("Trajectory summary:\n", "", regex=False)

# %%
def count_sentences(text):
    sentences = re.split(r'[.!?](?:\s|$)', text)
    sentences = [s.strip() for s in sentences if s.strip()]
    return len(sentences)

df["sentence_count"] = df["summaries"].apply(count_sentences)

# %%
df['outcome'] = df['filename'].apply(lambda x: 0 if 'deltaless' in str(x) else 1)

# %%
df.head()
# Out:
#                            filename  \
# 0  1062071645.0_1_delta_threads.xml
# 1  1075040167.0_1_delta_threads.xml
# 2   115882088.0_1_delta_threads.xml
# 3   113567594.0_1_delta_threads.xml
# 4  1082495263.0_2_delta_threads.xml
#
#                                            summaries  sentence_count  outcome
# 0  The original poster presents a critical argume...               5        1
# 1  The original poster makes a controversial clai...               5        1
# 2  The original poster shares personal observatio...               5        1
# 3  The original poster presents a pessimistic vie...               5        1
# 4  The original poster presents a concern about p...               4        1

# %% [markdown]
# ### summaries > prediction (yes or no)

# %%
#df_sampled = pd.read_csv(f'{cwd}/97_claude_summaries.csv')
df_sampled = pd.read_csv(f'{cwd}/74_claude_summaries.csv')

# %%
del df_sampled[df_sampled.columns[0]]

# %%
df_sampled
# Out:
#                                filename  outcome  \
# 0   1062071645.0_3_deltaless_thread.xml        0
# 1   1075040167.0_2_deltaless_thread.xml        0
# 2   1075040167.0_5_deltaless_thread.xml        0
# 3      1082495263.0_2_delta_threads.xml        1
# 4      1102614149.0_2_delta_threads.xml        1
# ..                                  ...      ...
# 69   410977978.0_3_deltaless_thread.xml        0
# 70      442068628.0_1_delta_threads.xml        1
# 71   442068628.0_4_deltaless_thread.xml        0
# 72      444945722.0_1_delta_threads.xml        1
# 73   444945722.0_1_deltaless_thread.xml        0
#
#                                     summary_corrected  corrected  \
# 0   The original poster shares a personal anecdote...          1
# 1   The original poster makes a controversial clai...          1
# 2   The original poster makes a controversial clai...          1
# 3   The original poster presents a concern, which ...          1
# 4   The original poster presents an interpretive q...          1
# ..                                                ...        ...
# 69  The original poster expresses extreme frustrat...          1
# 70  The original poster expresses pessimism about ...          1
# 71  The original poster expresses deep pessimism a...          1
# 72  The original poster presents a controversial v...          1
# 73  The original poster presents a controversial v...          1
#
#     sentence_count
# 0                4
# 1                4
# 2                4
# 3                5
# 4                4
# ..             ...
# 69               5
# 70               5
# 71               5
# 72               5
# 73               4
#
# [74 rows x 5 columns]

# %%
instructions = """
You are a moderator with expertise in linguistics. \
You will receive a summary of an online discussion thread, \
which includes the original post and subsequent comments. \
The summary highlights key moments where the tone or tension \
in the conversation shifts.

## Task
Analyze the summary and decide whether the conversation would have \
required moderator intervention to prevent or repair derailment.

Provide your answer with a simple 'Yes' or 'No', followed by a brief explanation.
"""

# %%
def prepare_batch_line(summary, instructions, i):

  system_prompt = instructions

  request = Request(
        custom_id=f"request-{i}",
        params=MessageCreateParamsNonStreaming(
            model="claude-opus-4-20250514",
            max_tokens=1024,
            system=[{
                "type": "text",
                "text": system_prompt,
                "cache_control": {"type": "ephemeral"}
                }],
            messages=[{
                "role": "user",
                "content": summary
                }],
            temperature=0
        )
    )

  return request

# %%
decision_dict = {}
batch_lines = []

i = 1

for index, row in tqdm(df_sampled.iterrows(), total=len(df_sampled)):
    #summary = row['response']
    summary = row['summary_corrected']
    fn = row['filename']

    req = prepare_batch_line(summary, instructions, i)
    decision_dict[f'request-{i}'] = fn
    i += 1
    batch_lines.append(req)
# Out:
# 100%|██████████| 74/74 [00:00<00:00, 10433.59it/s]

# %%
requests = []
for r in batch_lines:
  requests.append(r)

# %%
message_batch = client.messages.batches.create(requests=requests)
print(message_batch)

# %%
mbatch_id = message_batch.id

# %%
decision_dict
# Out:
# {'request-1': '1062071645.0_3_deltaless_thread.xml',
#  'request-2': '1075040167.0_2_deltaless_thread.xml',
#  'request-3': '1075040167.0_5_deltaless_thread.xml',
#  'request-4': '1082495263.0_2_delta_threads.xml',
#  'request-5': '1102614149.0_2_delta_threads.xml',
#  'request-6': '1102614149.0_4_deltaless_thread.xml',
#  'request-7': '113567594.0_1_delta_threads.xml',
#  'request-8': '113567594.0_4_deltaless_thread.xml',
#  'request-9': '115882088.0_1_delta_threads.xml',
#  'request-10': '115882088.0_2_deltaless_thread.xml',
#  'request-11': '134214340.0_1_delta_threads.xml',
#  'request-12': '134214340.0_11_deltaless_thread.xml',
#  'request-13': '1378810771.0_1_delta_threads.xml',
#  'request-14': '1437482501.0_1_delta_threads.xml',
#  'request-15': '1437482501.0_91_deltaless_thread.xml',
#  'request-16': '144404372.0_19_deltaless_thread.xml',
#  'request-17': '144404372.0_3_delta_threads.xml',
#  'request-18': '144404372.0_8_deltaless_thread.xml',
#  'request-19': '154839924.0_3_delta_threads.xml',
#  'request-20': '154839924.0_4_delta_threads.xml',
#  'request-21': '154839924.0_6_deltaless_thread.xml',
#  'request-22': '160170780.0_1_delta_threads.xml',
#  'request-23': '1719432989.0_1_delta_threads.xml',
#  'request-24': '181959121.0_5_deltaless_thread.xml',
#  'request-25': '1821161756.0_1_delta_threads.xml',
#  'request-26': '1821161756.0_2_delta_threads.xml',
#  'request-27': '1821161756.0_9_deltaless_thread.xml',
#  'request-28': '1865427692.0_1_delta_threads.xml',
#  'request-29': '1865427692.0_13_deltaless_thread.xml',
#  'request-30': '1865427692.0_2_delta_threads.xml',
#  'request-31': '1865427692.0_24_deltaless_thread.xml',
#  'request-32': '2076541612.0_1_delta_threads.xml',
#  'request-33': '2076541612.0_3_delta_threads.xml',
#  'request-34': '2076541612.0_3_deltaless_thread.xml',
#  'request-35': '2076541612.0_4_deltaless_thread.xml',
#  'request-36': '217468142.0_1_delta_threads.xml',
#  'request-37': '217468142.0_3_deltaless_thread.xml',
#  'request-38': '220698466.0_1_delta_threads.xml',
#  'request-39': '220698466.0_2_deltaless_thread.xml',
#  'request-40': '223614694.0_2_delta_threads.xml',
#  'request-41': '223614694.0_3_deltaless_thread.xml',
#  'request-42': '2242239967.0_10_deltaless_thread.xml',
#  'request-43': '2366753957.0_10_deltaless_thread.xml',
#  'request-44': '2366753957.0_2_deltaless_thread.xml',
#  'request-45': '2366753957.0_3_delta_threads.xml',
#  'request-46': '2366753957.0_3_deltaless_thread.xml',
#  'request-47': '2366753957.0_4_delta_threads.xml',
#  'request-48': '2366753957.0_5_delta_threads.xml',
#  'request-49': '2366753957.0_6_delta_threads.xml',
#  'request-50': '2366753957.0_7_delta_threads.xml',
#  'request-51': '2366753957.0_8_delta_threads.xml',
#  'request-52': '2512463257.0_1_delta_threads.xml',
#  'request-53': '2547064804.0_1_delta_threads.xml',
#  'request-54': '2547064804.0_2_deltaless_thread.xml',
#  'request-55': '2549309201.0_1_delta_threads.xml',
#  'request-56': '2549309201.0_2_deltaless_thread.xml',
#  'request-57': '258580368.0_1_delta_threads.xml',
#  'request-58': '258580368.0_2_deltaless_thread.xml',
#  'request-59': '2676326580.0_1_delta_threads.xml',
#  'request-60': '2676326580.0_26_deltaless_thread.xml',
#  'request-61': '2676326580.0_8_deltaless_thread.xml',
#  'request-62': '295203779.0_1_delta_threads.xml',
#  'request-63': '363480636.0_1_delta_threads.xml',
#  'request-64': '363480636.0_3_delta_threads.xml',
#  'request-65': '363480636.0_3_deltaless_thread.xml',
#  'request-66': '363480636.0_5_deltaless_thread.xml',
#  'request-67': '401821196.0_3_delta_threads.xml',
#  'request-68': '410977978.0_2_delta_threads.xml',
#  'request-69': '410977978.0_3_delta_threads.xml',
#  'request-70': '410977978.0_3_deltaless_thread.xml',
#  'request-71': '442068628.0_1_delta_threads.xml',
#  'request-72': '442068628.0_4_deltaless_thread.xml',
#  'request-73': '444945722.0_1_delta_threads.xml',
#  'request-74': '444945722.0_1_deltaless_thread.xml'}

# %%
message_batch = client.messages.batches.retrieve(
    mbatch_id,
)

print(message_batch)

# %% [markdown]
# # processing batch output (JSONL -> df)

# %%
import json

records = []

for result in client.messages.batches.results(mbatch_id):
    custom_id = result.custom_id

    text_blocks = result.result.message.content
    content_str = "".join(block.text for block in text_blocks if block.type == "text")

    flattened = {'custom_id': custom_id,
                 'response': content_str}

    records.append(flattened)

# %%
resp_df = pd.DataFrame(records)

# %%
print(resp_df.head())
# Out:
#    custom_id                                           response
# 0  request-1  Yes.\n\nThe conversation clearly deteriorated ...
# 1  request-2  No.\n\nWhile the conversation began with contr...
# 2  request-3  No.\n\nWhile the discussion involves controver...
# 3  request-4  No.\n\nThis appears to be a robust but civil d...
# 4  request-5  No.\n\nWhile the conversation shows increasing...

# %%
decisions_files = pd.DataFrame(list(decision_dict.items()), columns=["custom_id", "filename"])

# %%
resp_merged = resp_df.merge(decisions_files, on="custom_id", how="left")

# %%
split_cols = resp_merged["response"].str.split("\n\n", n=1, expand=True)
resp_merged["intervention"] = split_cols[0].str.lower().str.strip(". ")
resp_merged["reason"] = split_cols[1]

# %%
resp_merged['predicted'] = resp_merged['intervention'].apply(lambda x: 1 if 'no' in str(x) else 0)

# %%
resp_merged.head()
# Out:
#    custom_id                                           response  \
# 0  request-1  Yes.\n\nThe conversation clearly deteriorated ...
# 1  request-2  No.\n\nWhile the conversation began with contr...
# 2  request-3  No.\n\nWhile the discussion involves controver...
# 3  request-4  No.\n\nThis appears to be a robust but civil d...
# 4  request-5  No.\n\nWhile the conversation shows increasing...
#
#                               filename intervention  \
# 0  1062071645.0_3_deltaless_thread.xml          yes
# 1  1075040167.0_2_deltaless_thread.xml           no
# 2  1075040167.0_5_deltaless_thread.xml           no
# 3     1082495263.0_2_delta_threads.xml           no
# 4     1102614149.0_2_delta_threads.xml           no
#
#                                               reason  predicted
# 0  The conversation clearly deteriorated into per...          0
# 1  While the conversation began with controversy ...          1
# 2  While the discussion involves controversial cl...          1
# 3  This appears to be a robust but civil debate w...          1
# 4  While the conversation shows increasing tensio...          1

# %%
df_full = df_sampled.merge(resp_merged, on="filename", how="left")

# %%
df_full.to_csv(f'{cwd}/74_summaries_pred.csv', index=False)

# %%
correct_matches = (df_full["outcome"] == df_full["predicted"]).sum()
print(f"Number of correct predictions: {correct_matches}")
# Out:
# Number of correct predictions: 41

# %%
df_full
# Out:
#    custom_id_x                                         response_x  \
# 0    request-1  The original poster presents a critical view b...
# 1    request-2  The conversation begins with Speaker1 presenti...
# 2    request-3  The original poster presents a defense of farm...
# 3    request-4  The original poster presents a pessimistic vie...
# 4    request-5  The original poster presents a concern about p...
# ..         ...                                                ...
# 92  request-93  The original poster presents a controversial p...
# 93  request-94  The original poster expresses extreme frustrat...
# 94  request-95  The original poster expresses extreme frustrat...
# 95  request-96  The original poster expresses deep pessimism a...
# 96  request-97  Looking at this conversation thread, here's th...
#
#                               filename  sentence_count  outcome custom_id_y  \
# 0     1062071645.0_1_delta_threads.xml               4        1   request-1
# 1     1075040167.0_1_delta_threads.xml               5        1   request-2
# 2      115882088.0_1_delta_threads.xml               5        1   request-3
# 3      113567594.0_1_delta_threads.xml               4        1   request-4
# 4     1082495263.0_2_delta_threads.xml               5        1   request-5
# ..                                 ...             ...      ...         ...
# 92  363480636.0_3_deltaless_thread.xml               5        0  request-93
# 93  410977978.0_3_deltaless_thread.xml               5        0  request-94
# 94  410977978.0_4_deltaless_thread.xml               5        0  request-95
# 95  442068628.0_4_deltaless_thread.xml               5        0  request-96
# 96  444945722.0_1_deltaless_thread.xml               4        0  request-97
#
#                                            response_y intervention  \
# 0   No.\n\nWhile there is clear disagreement and s...           no
# 1   No.\n\nWhile the conversation shows increasing...           no
# 2   No.\n\nWhile the conversation contains disagre...           no
# 3   No.\n\nThis conversation shows healthy intelle...           no
# 4   No.\n\nWhile the conversation shows persistent...           no
# ..                                                ...          ...
# 92  Yes.\n\nThis conversation would have required ...          yes
# 93  Yes.\n\nThe conversation required moderator in...          yes
# 94  No.\n\nWhile the conversation contains tension...           no
# 95  No.\n\nThis conversation demonstrates healthy ...           no
# 96  No.\n\nWhile the conversation shows increasing...           no
#
#                                                reason  predicted
# 0   While there is clear disagreement and some per...          1
# 1   While the conversation shows increasing polari...          1
# 2   While the conversation contains disagreement a...          1
# 3   This conversation shows healthy intellectual d...          1
# 4   While the conversation shows persistent disagr...          1
# ..                                                ...        ...
# 92  This conversation would have required moderato...          0
# 93  The conversation required moderator interventi...          0
# 94  While the conversation contains tension and so...          1
# 95  This conversation demonstrates healthy discour...          1
# 96  While the conversation shows increasing tensio...          1
#
# [97 rows x 10 columns]

# %%
df.to_csv('claude_batch_output_sum.csv', index=False)
